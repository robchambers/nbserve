# %%
import IPython 
import runipy 
my_var = "old value" 
runipy.tempvar = "temp value"

# %%
print "Before reset, had 1: %s" % IPython 
print "Before reset, had 2: %s" % runipy 
print "Before reset, had 3: %s" % my_var 
print "Before reset, had 4: %s" % runipy.tempvar
# Out:
# Before reset, had 1: <module 'IPython' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/__init__.pyc'>
# Before reset, had 2: <module 'runipy' from '/Users/rob/anaconda/lib/python2.7/site-packages/runipy-0.1.5-py2.7.egg/runipy/__init__.pyc'>
# Before reset, had 3: old value
# Before reset, had 4: temp value

# %%
# %reset -f 
import sys 
sys.modules 
# del sys.modules['ConfigParser']
# Out:
# {'email.MIMEAudio': <email.LazyImporter at 0x1085032d0>,
#  'IPython.core.error': <module 'IPython.core.error' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/error.pyc'>,
#  'ipython_genutils.py3compat': <module 'ipython_genutils.py3compat' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipython_genutils/py3compat.pyc'>,
#  'traitlets.config.sys': None,
#  'ipykernel.parentpoller': <module 'ipykernel.parentpoller' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/parentpoller.pyc'>,
#  'traitlets.config.decorator': None,
#  'ctypes.os': None,
#  'pexpect.select': None,
#  'runpy': <module 'runpy' from '/Users/rob/anaconda/lib/python2.7/runpy.pyc'>,
#  'gc': <module 'gc' (built-in)>,
#  'pty': <module 'pty' from '/Users/rob/anaconda/lib/python2.7/pty.pyc'>,
#  'prompt_toolkit.terminal.vt100_output': <module 'prompt_toolkit.terminal.vt100_output' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/terminal/vt100_output.pyc'>,
#  'pkg_resources._vendor.traceback': None,
#  'prompt_toolkit.key_binding.six': None,
#  'pygments.filters': <module 'pygments.filters' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/filters/__init__.pyc'>,
#  'IPython.utils.pprint': None,
#  'jupyter_client.blocking.channels': <module 'jupyter_client.blocking.channels' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/blocking/channels.pyc'>,
#  'IPython.core.argparse': None,
#  'logging.weakref': None,
#  'traitlets.traitlets': <module 'traitlets.traitlets' from '/Users/rob/anaconda/lib/python2.7/site-packages/traitlets/traitlets.pyc'>,
#  'pprint': <module 'pprint' from '/Users/rob/anaconda/lib/python2.7/pprint.pyc'>,
#  'prompt_toolkit.key_binding.manager': <module 'prompt_toolkit.key_binding.manager' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/key_binding/manager.pyc'>,
#  'IPython.utils.simplegeneric': None,
#  'prompt_toolkit.key_binding.bindings.vi': <module 'prompt_toolkit.key_binding.bindings.vi' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/key_binding/bindings/vi.pyc'>,
#  'ipykernel.traitlets': None,
#  'IPython.core.magics.display': <module 'IPython.core.magics.display' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/display.pyc'>,
#  'timeit': <module 'timeit' from '/Users/rob/anaconda/lib/python2.7/timeit.pyc'>,
#  'IPython.core.magics.traitlets': None,
#  'IPython.terminal.sys': None,
#  'string': <module 'string' from '/Users/rob/anaconda/lib/python2.7/string.pyc'>,
#  'pexpect.utils': <module 'pexpect.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/pexpect/utils.pyc'>,
#  'prompt_toolkit.layout.six': None,
#  'multiprocessing.threading': None,
#  'IPython.utils.timing': <module 'IPython.utils.timing' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/timing.pyc'>,
#  'encodings.utf_8': <module 'encodings.utf_8' from '/Users/rob/anaconda/lib/python2.7/encodings/utf_8.pyc'>,
#  'email.quoprimime': <module 'email.quoprimime' from '/Users/rob/anaconda/lib/python2.7/email/quoprimime.pyc'>,
#  'json.encoder': <module 'json.encoder' from '/Users/rob/anaconda/lib/python2.7/json/encoder.pyc'>,
#  'datetime': <module 'datetime' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/datetime.so'>,
#  'IPython.core.magics.extension': <module 'IPython.core.magics.extension' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/extension.pyc'>,
#  'zmq.backend.cython.utils': <module 'zmq.backend.cython.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/utils.so'>,
#  'traitlets.six': None,
#  'ipython_genutils': <module 'ipython_genutils' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipython_genutils/__init__.pyc'>,
#  'prompt_toolkit.eventloop.abc': None,
#  'array': <module 'array' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/array.so'>,
#  'cmd': <module 'cmd' from '/Users/rob/anaconda/lib/python2.7/cmd.pyc'>,
#  'IPython.core.debugger': <module 'IPython.core.debugger' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/debugger.pyc'>,
#  'concurrent.futures.collections': None,
#  'IPython.core.displayhook': <module 'IPython.core.displayhook' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/displayhook.pyc'>,
#  'zmq.eventloop.Queue': None,
#  'IPython.lib.IPython': None,
#  'pygments.lexers.pygments': None,
#  'prompt_toolkit.styles.prompt_toolkit': None,
#  'shlex': <module 'shlex' from '/Users/rob/anaconda/lib/python2.7/shlex.pyc'>,
#  'zmq.backend.cython.zmq': None,
#  'IPython.core.ultratb': <module 'IPython.core.ultratb' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.pyc'>,
#  'prompt_toolkit.key_binding.vi_state': <module 'prompt_toolkit.key_binding.vi_state' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/key_binding/vi_state.pyc'>,
#  'ipywidgets.widgets.widget_bool': <module 'ipywidgets.widgets.widget_bool' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget_bool.pyc'>,
#  'prompt_toolkit.clipboard': <module 'prompt_toolkit.clipboard' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/clipboard/__init__.pyc'>,
#  'IPython.utils.resource': None,
#  'dis': <module 'dis' from '/Users/rob/anaconda/lib/python2.7/dis.pyc'>,
#  'prompt_toolkit.filters.utils': <module 'prompt_toolkit.filters.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/filters/utils.pyc'>,
#  'logging.threading': None,
#  'IPython.core.splitinput': <module 'IPython.core.splitinput' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/splitinput.pyc'>,
#  'IPython.lib.types': None,
#  'pkg_resources._vendor.pprint': None,
#  'ipywidgets.widgets.domwidget': <module 'ipywidgets.widgets.domwidget' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/domwidget.pyc'>,
#  'pexpect.spawnbase': <module 'pexpect.spawnbase' from '/Users/rob/anaconda/lib/python2.7/site-packages/pexpect/spawnbase.pyc'>,
#  'prompt_toolkit.__future__': None,
#  'IPython.terminal.unicodedata': None,
#  'IPython.core.excolors': <module 'IPython.core.excolors' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/excolors.pyc'>,
#  'jupyter_core.paths': <module 'jupyter_core.paths' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_core/paths.pyc'>,
#  'ptyprocess.termios': None,
#  'IPython.utils.tempfile': None,
#  'prompt_toolkit.layout.screen': <module 'prompt_toolkit.layout.screen' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/layout/screen.pyc'>,
#  'IPython.core.inspect': None,
#  'IPython.lib.getpass': None,
#  'abc': <module 'abc' from '/Users/rob/anaconda/lib/python2.7/abc.pyc'>,
#  'IPython.core.displaypub': <module 'IPython.core.displaypub' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/displaypub.pyc'>,
#  'IPython.utils._tokenize_py2': <module 'IPython.utils._tokenize_py2' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/_tokenize_py2.pyc'>,
#  'bdb': <module 'bdb' from '/Users/rob/anaconda/lib/python2.7/bdb.pyc'>,
#  'ast': <module 'ast' from '/Users/rob/anaconda/lib/python2.7/ast.pyc'>,
#  'ptyprocess': <module 'ptyprocess' from '/Users/rob/anaconda/lib/python2.7/site-packages/ptyprocess/__init__.pyc'>,
#  'IPython.core.mimetypes': None,
#  'traitlets.os': None,
#  'jupyter_client.blocking.client': <module 'jupyter_client.blocking.client' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/blocking/client.pyc'>,
#  'IPython.utils.io': <module 'IPython.utils.io' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/io.pyc'>,
#  'ntpath': <module 'ntpath' from '/Users/rob/anaconda/lib/python2.7/ntpath.pyc'>,
#  'IPython.terminal.__future__': None,
#  'zmq.sugar.warnings': None,
#  'runipy': <module 'runipy' from '/Users/rob/anaconda/lib/python2.7/site-packages/runipy-0.1.5-py2.7.egg/runipy/__init__.pyc'>,
#  'jupyter_client.adapter': <module 'jupyter_client.adapter' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/adapter.pyc'>,
#  'encodings.aliases': <module 'encodings.aliases' from '/Users/rob/anaconda/lib/python2.7/encodings/aliases.pyc'>,
#  'IPython.utils.openpy': <module 'IPython.utils.openpy' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/openpy.pyc'>,
#  'IPython.core.alias': <module 'IPython.core.alias' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/alias.pyc'>,
#  'inspect': <module 'inspect' from '/Users/rob/anaconda/lib/python2.7/inspect.pyc'>,
#  'ipykernel.warnings': None,
#  'IPython.core.datetime': None,
#  'IPython.terminal.pygments': None,
#  'prompt_toolkit.terminal': <module 'prompt_toolkit.terminal' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/terminal/__init__.pyc'>,
#  'ipython_genutils.re': None,
#  '_ctypes': <module '_ctypes' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_ctypes.so'>,
#  'glob': <module 'glob' from '/Users/rob/anaconda/lib/python2.7/glob.pyc'>,
#  'fnmatch': <module 'fnmatch' from '/Users/rob/anaconda/lib/python2.7/fnmatch.pyc'>,
#  'json.scanner': <module 'json.scanner' from '/Users/rob/anaconda/lib/python2.7/json/scanner.pyc'>,
#  'concurrent.futures.itertools': None,
#  'jupyter_client.hmac': None,
#  'codecs': <module 'codecs' from '/Users/rob/anaconda/lib/python2.7/codecs.pyc'>,
#  'ipykernel.re': None,
#  'prompt_toolkit.clipboard.six': None,
#  'IPython.core.shadowns': <module 'IPython.core.shadowns' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/shadowns.pyc'>,
#  'traitlets.config.loader': <module 'traitlets.config.loader' from '/Users/rob/anaconda/lib/python2.7/site-packages/traitlets/config/loader.pyc'>,
#  'pexpect.run': <module 'pexpect.run' from '/Users/rob/anaconda/lib/python2.7/site-packages/pexpect/run.pyc'>,
#  'pexpect.stat': None,
#  'ipython_genutils.locale': None,
#  'traitlets.config.json': None,
#  'ipykernel.datetime': None,
#  'IPython.utils.shutil': None,
#  'StringIO': <module 'StringIO' from '/Users/rob/anaconda/lib/python2.7/StringIO.pyc'>,
#  'ptyprocess.errno': None,
#  'concurrent.futures.atexit': None,
#  'pkg_resources': <module 'pkg_resources' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/__init__.py'>,
#  'weakref': <module 'weakref' from '/Users/rob/anaconda/lib/python2.7/weakref.pyc'>,
#  'prompt_toolkit.styles.__future__': None,
#  'traitlets': <module 'traitlets' from '/Users/rob/anaconda/lib/python2.7/site-packages/traitlets/__init__.pyc'>,
#  'ipywidgets.os': None,
#  'ipykernel.itertools': None,
#  'ptyprocess.resource': None,
#  'IPython.core.display': <module 'IPython.core.display' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/display.pyc'>,
#  'IPython.core.usage': <module 'IPython.core.usage' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/usage.pyc'>,
#  'ipykernel.heartbeat': <module 'ipykernel.heartbeat' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/heartbeat.pyc'>,
#  'IPython.terminal': <module 'IPython.terminal' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/__init__.pyc'>,
#  'base64': <module 'base64' from '/Users/rob/anaconda/lib/python2.7/base64.pyc'>,
#  'jupyter_client.os': None,
#  'ipykernel.traceback': None,
#  '_sre': <module '_sre' (built-in)>,
#  'pygments.formatters.html': <module 'pygments.formatters.html' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/formatters/html.pyc'>,
#  'email.FeedParser': <email.LazyImporter at 0x108503710>,
#  'IPython.core.json': None,
#  'traitlets.types': None,
#  'pyexpat.errors': <module 'pyexpat.errors' (built-in)>,
#  'email.charset': <module 'email.charset' from '/Users/rob/anaconda/lib/python2.7/email/charset.pyc'>,
#  'IPython': <module 'IPython' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/__init__.pyc'>,
#  'pkg_resources._vendor.datetime': None,
#  'prompt_toolkit.clipboard.prompt_toolkit': None,
#  'IPython.core.errno': None,
#  'select': <module 'select' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/select.so'>,
#  'ctypes._ctypes': None,
#  '_heapq': <module '_heapq' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_heapq.so'>,
#  'IPython.core.display_trap': <module 'IPython.core.display_trap' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/display_trap.pyc'>,
#  'zmq.sugar.constants': <module 'zmq.sugar.constants' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/constants.pyc'>,
#  'prompt_toolkit.key_binding.bindings.prompt_toolkit': None,
#  'zmq.backend.cython.time': None,
#  'binascii': <module 'binascii' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/binascii.so'>,
#  'IPython.lib.contextlib': None,
#  'pexpect.time': None,
#  'pygments.lexers.python': <module 'pygments.lexers.python' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/lexers/python.pyc'>,
#  'email.MIMEMessage': <email.LazyImporter at 0x108503310>,
#  'email._parseaddr': <module 'email._parseaddr' from '/Users/rob/anaconda/lib/python2.7/email/_parseaddr.pyc'>,
#  'email.sys': None,
#  'jupyter_client.manager': <module 'jupyter_client.manager' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/manager.pyc'>,
#  'tokenize': <module 'tokenize' from '/Users/rob/anaconda/lib/python2.7/tokenize.pyc'>,
#  'pygments.formatters.sys': None,
#  'IPython.core.StringIO': None,
#  'pkg_resources._vendor.six.moves.urllib': <module 'pkg_resources._vendor.six.moves.urllib' (built-in)>,
#  'IPython.core.magics.io': None,
#  'traitlets.utils.inspect': None,
#  'pkg_resources.extern.six.moves.urllib': <module 'pkg_resources._vendor.six.moves.urllib' (built-in)>,
#  'cPickle': <module 'cPickle' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/cPickle.so'>,
#  'jupyter_client.session': <module 'jupyter_client.session' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/session.pyc'>,
#  'ipykernel.comm.ipykernel': None,
#  'prompt_toolkit.pygments': None,
#  'IPython.core.magics.errno': None,
#  'jupyter_client.blocking.jupyter_client': None,
#  'IPython.utils.encoding': <module 'IPython.utils.encoding' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/encoding.pyc'>,
#  '_curses': <module '_curses' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_curses.so'>,
#  'IPython.core.ast': None,
#  'IPython.core.keyword': None,
#  'IPython.lib.os': None,
#  'prompt_toolkit.clipboard.base': <module 'prompt_toolkit.clipboard.base' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/clipboard/base.pyc'>,
#  'prompt_toolkit.styles.abc': None,
#  'prompt_toolkit.terminal.__future__': None,
#  'zmq.backend.cython.cPickle': None,
#  'IPython.core.getipython': <module 'IPython.core.getipython' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/getipython.pyc'>,
#  'ipykernel.cPickle': None,
#  'prompt_toolkit.key_binding.input_processor': <module 'prompt_toolkit.key_binding.input_processor' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/key_binding/input_processor.pyc'>,
#  'unicodedata': <module 'unicodedata' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/unicodedata.so'>,
#  'zmq': <module 'zmq' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/__init__.pyc'>,
#  'IPython.core.page': <module 'IPython.core.page' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/page.pyc'>,
#  '_ast': <module '_ast' (built-in)>,
#  'IPython.utils.process': <module 'IPython.utils.process' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/process.pyc'>,
#  'jupyter_client.sys': None,
#  'prompt_toolkit.styles.pygments': None,
#  'jupyter_client.io': None,
#  'zmq.sugar.tracker': <module 'zmq.sugar.tracker' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/tracker.pyc'>,
#  'pkg_resources._vendor.copy': None,
#  'zmq.backend.cython.codecs': None,
#  'IPython.extensions.textwrap': None,
#  'ptyprocess.pty': None,
#  'exceptions': <module 'exceptions' (built-in)>,
#  'sre_parse': <module 'sre_parse' from '/Users/rob/anaconda/lib/python2.7/sre_parse.pyc'>,
#  'tornado.concurrent': <module 'tornado.concurrent' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/concurrent.pyc'>,
#  'pickle': <module 'pickle' from '/Users/rob/anaconda/lib/python2.7/pickle.pyc'>,
#  'jupyter_core.version': <module 'jupyter_core.version' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_core/version.pyc'>,
#  'ipywidgets.widgets.ipykernel': None,
#  'numbers': <module 'numbers' from '/Users/rob/anaconda/lib/python2.7/numbers.pyc'>,
#  'pygments.regexopt': <module 'pygments.regexopt' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/regexopt.pyc'>,
#  'zmq.sugar.version': <module 'zmq.sugar.version' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/version.pyc'>,
#  'jupyter_client.launcher': <module 'jupyter_client.launcher' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/launcher.pyc'>,
#  'logging.cStringIO': None,
#  'IPython.terminal.debugger': <module 'IPython.terminal.debugger' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/debugger.pyc'>,
#  'pkg_resources._vendor.os': None,
#  'pkg_resources.extern.six': <module 'pkg_resources._vendor.six' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/six.py'>,
#  'prompt_toolkit.styles.six': None,
#  '_scandir': <module '_scandir' from '/Users/rob/anaconda/lib/python2.7/site-packages/_scandir.so'>,
#  'IPython.utils.shlex': None,
#  'IPython.core.magics.signal': None,
#  'ipywidgets.widgets.interaction': <module 'ipywidgets.widgets.interaction' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/interaction.pyc'>,
#  'ipykernel.comm.ipython_genutils': None,
#  'runipy._version': <module 'runipy._version' from '/Users/rob/anaconda/lib/python2.7/site-packages/runipy-0.1.5-py2.7.egg/runipy/_version.pyc'>,
#  'traitlets.inspect': None,
#  'email.message': <module 'email.message' from '/Users/rob/anaconda/lib/python2.7/email/message.pyc'>,
#  'email.Header': <email.LazyImporter at 0x108503610>,
#  'ipykernel.zmq': None,
#  'IPython.utils.platform': None,
#  'strop': <module 'strop' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/strop.so'>,
#  'pygments.util': <module 'pygments.util' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/util.pyc'>,
#  'jupyter_client.jupyter_client': None,
#  'IPython.core.history': <module 'IPython.core.history' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/history.pyc'>,
#  'concurrent.futures.process': <module 'concurrent.futures.process' from '/Users/rob/anaconda/lib/python2.7/site-packages/concurrent/futures/process.pyc'>,
#  'six': <module 'six' from '/Users/rob/anaconda/lib/python2.7/site-packages/six.pyc'>,
#  'IPython.shutil': None,
#  'jupyter_client.connect': <module 'jupyter_client.connect' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/connect.pyc'>,
#  'ipywidgets.widgets.__future__': None,
#  'ipython_genutils.textwrap': None,
#  'zmq.backend.cython.struct': None,
#  'prompt_toolkit.abc': None,
#  'IPython.utils.ipstruct': <module 'IPython.utils.ipstruct' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/ipstruct.pyc'>,
#  'traitlets._version': <module 'traitlets._version' from '/Users/rob/anaconda/lib/python2.7/site-packages/traitlets/_version.pyc'>,
#  'prompt_toolkit.eventloop.callbacks': <module 'prompt_toolkit.eventloop.callbacks' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/eventloop/callbacks.pyc'>,
#  'prompt_toolkit.eventloop.base': <module 'prompt_toolkit.eventloop.base' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/eventloop/base.pyc'>,
#  'IPython.extensions.__future__': None,
#  'jupyter_client.jupyter_core': None,
#  'concurrent.pkgutil': None,
#  'ctypes.util': <module 'ctypes.util' from '/Users/rob/anaconda/lib/python2.7/ctypes/util.pyc'>,
#  'ipykernel.copy': None,
#  'htmlentitydefs': <module 'htmlentitydefs' from '/Users/rob/anaconda/lib/python2.7/htmlentitydefs.pyc'>,
#  'zmq.backend.cython.threading': None,
#  'zmq.eventloop.sys': None,
#  'ipywidgets.widgets.contextlib': None,
#  'jupyter_client.blocking': <module 'jupyter_client.blocking' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/blocking/__init__.pyc'>,
#  'pexpect.os': None,
#  'codeop': <module 'codeop' from '/Users/rob/anaconda/lib/python2.7/codeop.pyc'>,
#  'email.parser': <module 'email.parser' from '/Users/rob/anaconda/lib/python2.7/email/parser.pyc'>,
#  'pkg_resources._vendor.__builtin__': None,
#  'os.path': <module 'posixpath' from '/Users/rob/anaconda/lib/python2.7/posixpath.pyc'>,
#  'IPython.core.magics.time': None,
#  'argparse': <module 'argparse' from '/Users/rob/anaconda/lib/python2.7/argparse.pyc'>,
#  'pkg_resources.extern.packaging.specifiers': <module 'pkg_resources._vendor.packaging.specifiers' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/packaging/specifiers.py'>,
#  'email.base64mime': <module 'email.base64mime' from '/Users/rob/anaconda/lib/python2.7/email/base64mime.pyc'>,
#  'IPython.core.tempfile': None,
#  'IPython.core.payload': <module 'IPython.core.payload' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/payload.pyc'>,
#  '_weakrefset': <module '_weakrefset' from '/Users/rob/anaconda/lib/python2.7/_weakrefset.pyc'>,
#  'zmq.backend.select': <module 'zmq.backend.select' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/select.pyc'>,
#  'email.string': None,
#  'prompt_toolkit.bisect': None,
#  'ipywidgets.widgets.widget': <module 'ipywidgets.widgets.widget' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget.pyc'>,
#  'traitlets.config.configurable': <module 'traitlets.config.configurable' from '/Users/rob/anaconda/lib/python2.7/site-packages/traitlets/config/configurable.pyc'>,
#  '_cython_0_25_1': <module '_cython_0_25_1' (built-in)>,
#  'IPython.core.traitlets': None,
#  'tty': <module 'tty' from '/Users/rob/anaconda/lib/python2.7/tty.pyc'>,
#  'ipykernel.threading': None,
#  'pexpect.exceptions': <module 'pexpect.exceptions' from '/Users/rob/anaconda/lib/python2.7/site-packages/pexpect/exceptions.pyc'>,
#  'prompt_toolkit.io': None,
#  'pygments.pygments': None,
#  'functools': <module 'functools' from '/Users/rob/anaconda/lib/python2.7/functools.pyc'>,
#  'pkg_resources._vendor.weakref': None,
#  'prompt_toolkit.subprocess': None,
#  'backports.shutil_get_terminal_size.termios': None,
#  'sysconfig': <module 'sysconfig' from '/Users/rob/anaconda/lib/python2.7/sysconfig.pyc'>,
#  'IPython.terminal.embed': <module 'IPython.terminal.embed' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/embed.pyc'>,
#  'email.MIMEImage': <email.LazyImporter at 0x1085031d0>,
#  'concurrent.futures.concurrent': None,
#  'ipykernel.serialize': <module 'ipykernel.serialize' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/serialize.pyc'>,
#  'jupyter_client._version': <module 'jupyter_client._version' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/_version.pyc'>,
#  'pexpect.contextlib': None,
#  'email.MIMEText': <email.LazyImporter at 0x1084ed590>,
#  'pygments.formatters.types': None,
#  'zmq.backend.cython.error': <module 'zmq.backend.cython.error' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/error.so'>,
#  'prompt_toolkit.eventloop.__future__': None,
#  '_bisect': <module '_bisect' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_bisect.so'>,
#  'uuid': <module 'uuid' from '/Users/rob/anaconda/lib/python2.7/uuid.pyc'>,
#  'jupyter_core.os': None,
#  'tempfile': <module 'tempfile' from '/Users/rob/anaconda/lib/python2.7/tempfile.pyc'>,
#  'pydap.handlers': <module 'pydap.handlers' (built-in)>,
#  'prompt_toolkit.tempfile': None,
#  'imp': <module 'imp' (built-in)>,
#  'pkg_resources._vendor': <module 'pkg_resources._vendor' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/__init__.py'>,
#  'prompt_toolkit.wcwidth': None,
#  'multiprocessing.os': None,
#  'pydap.responses': <module 'pydap.responses' (built-in)>,
#  'IPython.utils.tempdir': <module 'IPython.utils.tempdir' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/tempdir.pyc'>,
#  'zmq.utils.constant_names': <module 'zmq.utils.constant_names' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/utils/constant_names.pyc'>,
#  'multiprocessing.itertools': None,
#  'backports.shutil_get_terminal_size.collections': None,
#  'enum.sys': None,
#  'zmq.libzmq': <module 'zmq.libzmq' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/libzmq.so'>,
#  'jupyter_client.random': None,
#  'traitlets.utils.sentinel': <module 'traitlets.utils.sentinel' from '/Users/rob/anaconda/lib/python2.7/site-packages/traitlets/utils/sentinel.pyc'>,
#  'ptyprocess.os': None,
#  'pexpect.codecs': None,
#  'zmq.zmq': None,
#  'ptyprocess.codecs': None,
#  'prompt_toolkit.input': <module 'prompt_toolkit.input' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/input.pyc'>,
#  'pkg_resources._vendor.six': <module 'pkg_resources._vendor.six' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/six.py'>,
#  'email.email': None,
#  'IPython.core.traceback': None,
#  'email.codecs': None,
#  'IPython.core.__main__': None,
#  'IPython.extensions.inspect': None,
#  'ipython_genutils._version': <module 'ipython_genutils._version' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipython_genutils/_version.pyc'>,
#  'prompt_toolkit.layout.mouse_handlers': <module 'prompt_toolkit.layout.mouse_handlers' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/layout/mouse_handlers.pyc'>,
#  'IPython.utils.hashlib': None,
#  'email.urllib': None,
#  'zmq.eventloop.__future__': None,
#  'decorator': <module 'decorator' from '/Users/rob/anaconda/lib/python2.7/site-packages/decorator.pyc'>,
#  'IPython.core.zipimport': None,
#  'pygments.lexers.sys': None,
#  'pygments.unistring': <module 'pygments.unistring' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/unistring.pyc'>,
#  'IPython.terminal.interactiveshell': <module 'IPython.terminal.interactiveshell' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/interactiveshell.pyc'>,
#  'IPython.extensions.traitlets': None,
#  'zmq.backend.cython.context': <module 'zmq.backend.cython.context' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/context.so'>,
#  'IPython.core.warnings': None,
#  'IPython.utils.imp': None,
#  'logging.handlers': <module 'logging.handlers' from '/Users/rob/anaconda/lib/python2.7/logging/handlers.pyc'>,
#  'token': <module 'token' from '/Users/rob/anaconda/lib/python2.7/token.pyc'>,
#  'email.encoders': <module 'email.encoders' from '/Users/rob/anaconda/lib/python2.7/email/encoders.pyc'>,
#  'prompt_toolkit.auto_suggest': <module 'prompt_toolkit.auto_suggest' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/auto_suggest.pyc'>,
#  'prompt_toolkit.buffer': <module 'prompt_toolkit.buffer' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/buffer.pyc'>,
#  'ipywidgets.widgets.IPython': None,
#  'IPython.testing.sys': None,
#  'pygments.formatters.os': None,
#  'IPython.utils.warnings': None,
#  'IPython.core.magics.gc': None,
#  'ptyprocess.fcntl': None,
#  'cStringIO': <module 'cStringIO' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/cStringIO.so'>,
#  'IPython.utils.errno': None,
#  'backports.shutil_get_terminal_size.struct': None,
#  'IPython.core.io': None,
#  'prompt_toolkit.key_binding.prompt_toolkit': None,
#  'IPython.core.magics.namespace': <module 'IPython.core.magics.namespace' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/namespace.pyc'>,
#  'traitlets.config.copy': None,
#  'ipywidgets.widgets.widget_color': <module 'ipywidgets.widgets.widget_color' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget_color.pyc'>,
#  'traitlets.utils.ipython_genutils': None,
#  'curses.os': None,
#  'zmq.sugar.frame': <module 'zmq.sugar.frame' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/frame.pyc'>,
#  'multiprocessing.process': <module 'multiprocessing.process' from '/Users/rob/anaconda/lib/python2.7/multiprocessing/process.pyc'>,
#  'pkg_resources.extern.packaging.requirements': <module 'pkg_resources._vendor.packaging.requirements' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/packaging/requirements.py'>,
#  'encodings': <module 'encodings' from '/Users/rob/anaconda/lib/python2.7/encodings/__init__.pyc'>,
#  'IPython.core.magics.history': <module 'IPython.core.magics.history' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/history.pyc'>,
#  'IPython.core.__future__': None,
#  'zmq.utils.strtypes': <module 'zmq.utils.strtypes' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/utils/strtypes.pyc'>,
#  'pexpect.expect': <module 'pexpect.expect' from '/Users/rob/anaconda/lib/python2.7/site-packages/pexpect/expect.pyc'>,
#  'prompt_toolkit.layout.toolbars': <module 'prompt_toolkit.layout.toolbars' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/layout/toolbars.pyc'>,
#  'ipykernel.comm.uuid': None,
#  'IPython.core.interactiveshell': <module 'IPython.core.interactiveshell' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc'>,
#  'traitlets.ipython_genutils': None,
#  'IPython.core.operator': None,
#  'IPython.core.crashhandler': <module 'IPython.core.crashhandler' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/crashhandler.pyc'>,
#  'IPython.utils': <module 'IPython.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/__init__.pyc'>,
#  'zmq.ctypes': None,
#  'prompt_toolkit.layout.time': None,
#  'prompt_toolkit.threading': None,
#  'pkg_resources._vendor.packaging.__about__': <module 'pkg_resources._vendor.packaging.__about__' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/packaging/__about__.py'>,
#  're': <module 're' from '/Users/rob/anaconda/lib/python2.7/re.pyc'>,
#  'pygments.filters.re': None,
#  'jupyter_client.warnings': None,
#  'email.quopri': None,
#  'IPython.utils.capture': <module 'IPython.utils.capture' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/capture.pyc'>,
#  'ipykernel.errno': None,
#  'ipykernel.ipkernel': <module 'ipykernel.ipkernel' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/ipkernel.pyc'>,
#  'sqlite3.time': None,
#  'math': <module 'math' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/math.so'>,
#  'IPython.core.IPython': None,
#  'pydap': <module 'pydap' (built-in)>,
#  'wcwidth.__future__': None,
#  'ipykernel.comm.manager': <module 'ipykernel.comm.manager' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/comm/manager.pyc'>,
#  'IPython.core.importlib': None,
#  'ipython_genutils.errno': None,
#  'IPython.lib.sys': None,
#  'prompt_toolkit.interface': <module 'prompt_toolkit.interface' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/interface.pyc'>,
#  'email.re': None,
#  'prompt_toolkit.terminal.vt100_input': <module 'prompt_toolkit.terminal.vt100_input' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/terminal/vt100_input.pyc'>,
#  'prompt_toolkit.key_binding.bindings.six': None,
#  'ctypes.struct': None,
#  'IPython.utils.colorable': <module 'IPython.utils.colorable' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/colorable.pyc'>,
#  'ipykernel.ctypes': None,
#  '_scproxy': <module '_scproxy' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_scproxy.so'>,
#  'prompt_toolkit.filters': <module 'prompt_toolkit.filters' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/filters/__init__.pyc'>,
#  '_locale': <module '_locale' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_locale.so'>,
#  'IPython.core.logging': None,
#  'logging': <module 'logging' from '/Users/rob/anaconda/lib/python2.7/logging/__init__.pyc'>,
#  'prompt_toolkit.enums': <module 'prompt_toolkit.enums' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/enums.pyc'>,
#  'thread': <module 'thread' (built-in)>,
#  'ipywidgets.widgets.widget_link': <module 'ipywidgets.widgets.widget_link' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget_link.pyc'>,
#  'sqlite3.dbapi2': <module 'sqlite3.dbapi2' from '/Users/rob/anaconda/lib/python2.7/sqlite3/dbapi2.pyc'>,
#  'traceback': <module 'traceback' from '/Users/rob/anaconda/lib/python2.7/traceback.pyc'>,
#  'ipykernel.signal': None,
#  'multiprocessing': <module 'multiprocessing' from '/Users/rob/anaconda/lib/python2.7/multiprocessing/__init__.pyc'>,
#  'concurrent.futures.time': None,
#  'IPython.core.copy': None,
#  'IPython.core.builtin_trap': <module 'IPython.core.builtin_trap' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/builtin_trap.pyc'>,
#  'zmq.backend.platform': None,
#  'IPython.utils.coloransi': <module 'IPython.utils.coloransi' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/coloransi.pyc'>,
#  'multiprocessing.util': <module 'multiprocessing.util' from '/Users/rob/anaconda/lib/python2.7/multiprocessing/util.pyc'>,
#  'IPython.utils._process_posix': <module 'IPython.utils._process_posix' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/_process_posix.pyc'>,
#  'IPython.core.completerlib': <module 'IPython.core.completerlib' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/completerlib.pyc'>,
#  'pkg_resources._vendor.packaging.markers': <module 'pkg_resources._vendor.packaging.markers' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/packaging/markers.py'>,
#  'pkg_resources._vendor.packaging.version': <module 'pkg_resources._vendor.packaging.version' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/packaging/version.py'>,
#  'ipywidgets.widgets.widget_layout': <module 'ipywidgets.widgets.widget_layout' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget_layout.pyc'>,
#  'prompt_toolkit.filters.six': None,
#  '_collections': <module '_collections' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_collections.so'>,
#  'ctypes.macholib.os': None,
#  'prompt_toolkit.mouse_events': <module 'prompt_toolkit.mouse_events' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/mouse_events.pyc'>,
#  'ipykernel.jupyter_core': None,
#  'jupyter_client.multikernelmanager': <module 'jupyter_client.multikernelmanager' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/multikernelmanager.pyc'>,
#  'prompt_toolkit.key_binding.bindings.__future__': None,
#  'ipykernel.kernelbase': <module 'ipykernel.kernelbase' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/kernelbase.pyc'>,
#  'traitlets.config.ast': None,
#  'multiprocessing.sys': None,
#  'ipykernel.uuid': None,
#  'ipywidgets.widgets.widget_button': <module 'ipywidgets.widgets.widget_button' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget_button.pyc'>,
#  'pexpect.pty_spawn': <module 'pexpect.pty_spawn' from '/Users/rob/anaconda/lib/python2.7/site-packages/pexpect/pty_spawn.pyc'>,
#  'pygments.filter': <module 'pygments.filter' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/filter.pyc'>,
#  'email.Errors': <email.LazyImporter at 0x108503790>,
#  'IPython.utils.locale': None,
#  'ctypes.sys': None,
#  'IPython.core.magics.config': <module 'IPython.core.magics.config' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/config.pyc'>,
#  'pygments.lexers.__future__': None,
#  'pexpect': <module 'pexpect' from '/Users/rob/anaconda/lib/python2.7/site-packages/pexpect/__init__.pyc'>,
#  'posixpath': <module 'posixpath' from '/Users/rob/anaconda/lib/python2.7/posixpath.pyc'>,
#  'jupyter_client.channels': <module 'jupyter_client.channels' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/channels.pyc'>,
#  'prompt_toolkit.key_binding.collections': None,
#  'pkg_resources._vendor.packaging._compat': <module 'pkg_resources._vendor.packaging._compat' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/packaging/_compat.py'>,
#  'pygments.formatter': <module 'pygments.formatter' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/formatter.pyc'>,
#  'IPython.utils._sysinfo': <module 'IPython.utils._sysinfo' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/_sysinfo.pyc'>,
#  'prompt_toolkit.filters.cli': <module 'prompt_toolkit.filters.cli' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/filters/cli.pyc'>,
#  'traitlets.logging': None,
#  'ipykernel.types': None,
#  'types': <module 'types' from '/Users/rob/anaconda/lib/python2.7/types.pyc'>,
#  'zmq.backend.cython._device': <module 'zmq.backend.cython._device' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/_device.so'>,
#  'prompt_toolkit.styles.from_dict': <module 'prompt_toolkit.styles.from_dict' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/styles/from_dict.pyc'>,
#  'prompt_toolkit.utils': <module 'prompt_toolkit.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/utils.pyc'>,
#  'prompt_toolkit.clipboard.in_memory': <module 'prompt_toolkit.clipboard.in_memory' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/clipboard/in_memory.pyc'>,
#  'IPython.core.linecache': None,
#  'ipywidgets.widgets.widget_string': <module 'ipywidgets.widgets.widget_string' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget_string.pyc'>,
#  'json._json': None,
#  'curses.sys': None,
#  'ipykernel.jupyter_client': None,
#  '_codecs': <module '_codecs' (built-in)>,
#  'traitlets.contextlib': None,
#  'ipykernel.comm.sys': None,
#  'IPython.core.unicodedata': None,
#  'enum.collections': None,
#  'json.sys': None,
#  'zmq.eventloop.tornado': None,
#  'IPython.utils.os': None,
#  '_osx_support': <module '_osx_support' from '/Users/rob/anaconda/lib/python2.7/_osx_support.pyc'>,
#  'ipykernel.datapub': <module 'ipykernel.datapub' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/datapub.pyc'>,
#  'ctypes.macholib.dyld': <module 'ctypes.macholib.dyld' from '/Users/rob/anaconda/lib/python2.7/ctypes/macholib/dyld.pyc'>,
#  'concurrent.futures.multiprocessing': None,
#  'pygments.time': None,
#  'zmq.eventloop.ioloop': <module 'zmq.eventloop.ioloop' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/eventloop/ioloop.pyc'>,
#  'copy': <module 'copy' from '/Users/rob/anaconda/lib/python2.7/copy.pyc'>,
#  'IPython.core.magics.IPython': None,
#  'prompt_toolkit.styles.collections': None,
#  'ipykernel.comm.logging': None,
#  'ipython_genutils.shutil': None,
#  'hashlib': <module 'hashlib' from '/Users/rob/anaconda/lib/python2.7/hashlib.pyc'>,
#  'prompt_toolkit': <module 'prompt_toolkit' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/__init__.pyc'>,
#  'email.errors': <module 'email.errors' from '/Users/rob/anaconda/lib/python2.7/email/errors.pyc'>,
#  'keyword': <module 'keyword' from '/Users/rob/anaconda/lib/python2.7/keyword.pyc'>,
#  'ipython_genutils.random': None,
#  'ipywidgets.widgets.jupyter_client': None,
#  'prompt_toolkit.output': <module 'prompt_toolkit.output' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/output.pyc'>,
#  'IPython.extensions.IPython': None,
#  'ipywidgets.widgets.sys': None,
#  'posix': <module 'posix' (built-in)>,
#  'IPython.core.hashlib': None,
#  'pygments.lexers.fnmatch': None,
#  'IPython.core.autocall': <module 'IPython.core.autocall' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/autocall.pyc'>,
#  'IPython.utils.generics': <module 'IPython.utils.generics' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/generics.pyc'>,
#  'ipykernel.connect': <module 'ipykernel.connect' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/connect.pyc'>,
#  'backports.shutil_get_terminal_size.os': None,
#  'ipywidgets.IPython': None,
#  'prompt_toolkit.layout.collections': None,
#  'sre_compile': <module 'sre_compile' from '/Users/rob/anaconda/lib/python2.7/sre_compile.pyc'>,
#  'ipykernel': <module 'ipykernel' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/__init__.pyc'>,
#  '_hashlib': <module '_hashlib' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_hashlib.so'>,
#  'prompt_toolkit.layout.utils': <module 'prompt_toolkit.layout.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/layout/utils.pyc'>,
#  'prompt_toolkit.shortcuts': <module 'prompt_toolkit.shortcuts' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/shortcuts.pyc'>,
#  'IPython.utils.ulinecache': <module 'IPython.utils.ulinecache' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/ulinecache.pyc'>,
#  'zmq.eventloop.cPickle': None,
#  'IPython.core.magics.code': <module 'IPython.core.magics.code' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/code.pyc'>,
#  'IPython.core.sqlite3': None,
#  'IPython.core.bdb': None,
#  'logging.collections': None,
#  'IPython.core.threading': None,
#  'email.base64': None,
#  'encodings.string_escape': <module 'encodings.string_escape' from '/Users/rob/anaconda/lib/python2.7/encodings/string_escape.pyc'>,
#  'pygments.__future__': None,
#  '__main__': <module '__main__' (built-in)>,
#  'multiprocessing.atexit': None,
#  'zmq.backend.cython.message': <module 'zmq.backend.cython.message' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/message.so'>,
#  'prompt_toolkit.string': None,
#  'prompt_toolkit.layout.re': None,
#  'pexpect.pty': None,
#  'prompt_toolkit.layout.__future__': None,
#  'prompt_toolkit.token': <module 'prompt_toolkit.token' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/token.pyc'>,
#  'IPython.utils.terminal': <module 'IPython.utils.terminal' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/terminal.pyc'>,
#  'jupyter_client.ipython_genutils': None,
#  'encodings.codecs': None,
#  'ipywidgets.widgets.widget_selection': <module 'ipywidgets.widgets.widget_selection' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget_selection.pyc'>,
#  'ipywidgets': <module 'ipywidgets' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/__init__.pyc'>,
#  'IPython.utils.__builtin__': None,
#  'IPython.terminal.os': None,
#  'IPython.lib.threading': None,
#  'zmq.utils.jsonapi': <module 'zmq.utils.jsonapi' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/utils/jsonapi.pyc'>,
#  'email.MIMEMultipart': <email.LazyImporter at 0x1081513d0>,
#  'curses.curses': None,
#  'ipykernel.IPython': None,
#  'IPython.core.completer': <module 'IPython.core.completer' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/completer.pyc'>,
#  'ipykernel.base64': None,
#  '_ssl': <module '_ssl' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_ssl.so'>,
#  'pexpect.ptyprocess': None,
#  'IPython.utils.sys': None,
#  'IPython.utils.re': None,
#  'tornado': <module 'tornado' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/__init__.pyc'>,
#  'IPython.lib.clipboard': <module 'IPython.lib.clipboard' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/clipboard.pyc'>,
#  'encodings.ascii': <module 'encodings.ascii' from '/Users/rob/anaconda/lib/python2.7/encodings/ascii.pyc'>,
#  'ipykernel.getpass': None,
#  'multiprocessing.multiprocessing': None,
#  'IPython.utils.inspect': None,
#  'zmq.backend.cython.sys': None,
#  'IPython.core.base64': None,
#  'pkg_resources.extern.appdirs': <module 'pkg_resources._vendor.appdirs' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/appdirs.py'>,
#  'pexpect.errno': None,
#  '_sqlite3': <module '_sqlite3' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_sqlite3.so'>,
#  'ipython_genutils.text': <module 'ipython_genutils.text' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipython_genutils/text.pyc'>,
#  'IPython.core.shellapp': <module 'IPython.core.shellapp' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/shellapp.pyc'>,
#  'email.feedparser': <module 'email.feedparser' from '/Users/rob/anaconda/lib/python2.7/email/feedparser.pyc'>,
#  'email.MIMEBase': <email.LazyImporter at 0x108503250>,
#  'prompt_toolkit.selection': <module 'prompt_toolkit.selection' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/selection.pyc'>,
#  'plistlib': <module 'plistlib' from '/Users/rob/anaconda/lib/python2.7/plistlib.pyc'>,
#  'multiprocessing._multiprocessing': None,
#  'ctypes.macholib': <module 'ctypes.macholib' from '/Users/rob/anaconda/lib/python2.7/ctypes/macholib/__init__.pyc'>,
#  'concurrent.futures.sys': None,
#  'pygments.modeline': <module 'pygments.modeline' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/modeline.pyc'>,
#  'pkg_resources._vendor.collections': None,
#  'IPython.utils.wildcard': <module 'IPython.utils.wildcard' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/wildcard.pyc'>,
#  'IPython.core.extensions': <module 'IPython.core.extensions' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/extensions.pyc'>,
#  'IPython.utils.tokenutil': <module 'IPython.utils.tokenutil' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/tokenutil.pyc'>,
#  '_io': <module '_io' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_io.so'>,
#  'linecache': <module 'linecache' from '/Users/rob/anaconda/lib/python2.7/linecache.pyc'>,
#  '_strptime': <module '_strptime' from '/Users/rob/anaconda/lib/python2.7/_strptime.pyc'>,
#  'ipywidgets.widgets.trait_types': <module 'ipywidgets.widgets.trait_types' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/trait_types.pyc'>,
#  'IPython.core.compilerop': <module 'IPython.core.compilerop' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/compilerop.pyc'>,
#  'ipykernel.comm': <module 'ipykernel.comm' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/comm/__init__.pyc'>,
#  'jupyter_client.zmq': None,
#  'hmac': <module 'hmac' from '/Users/rob/anaconda/lib/python2.7/hmac.pyc'>,
#  'tornado.platform.interface': <module 'tornado.platform.interface' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/platform/interface.pyc'>,
#  'scandir': <module 'scandir' from '/Users/rob/anaconda/lib/python2.7/site-packages/scandir.pyc'>,
#  'prompt_toolkit.terminal.six': None,
#  'ipywidgets.widgets.widget_output': <module 'ipywidgets.widgets.widget_output' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget_output.pyc'>,
#  'email.iterators': <module 'email.iterators' from '/Users/rob/anaconda/lib/python2.7/email/iterators.pyc'>,
#  '_multiprocessing': <module '_multiprocessing' from '/Users/rob/anaconda/lib/python2.7/lib-dynload/_multiprocessing.so'>,
#  'ipywidgets.widgets.traitlets': None,
#  'IPython.core.magics.osm': <module 'IPython.core.magics.osm' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/osm.pyc'>,
#  'jupyter_client.json': None,
#  'random': <module 'random' from '/Users/rob/anaconda/lib/python2.7/random.pyc'>,
#  'jupyter_core.sys': None,
#  'pygments.styles': <module 'pygments.styles' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/styles/__init__.pyc'>,
#  'zmq.sugar.context': <module 'zmq.sugar.context' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/context.pyc'>,
#  'subprocess': <module 'subprocess' from '/Users/rob/anaconda/lib/python2.7/subprocess.pyc'>,
#  'IPython.extensions.storemagic': <module 'IPython.extensions.storemagic' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/extensions/storemagic.pyc'>,
#  'prompt_toolkit.key_binding.weakref': None,
#  'backports.shutil_get_terminal_size.fcntl': None,
#  'ipython_genutils.sys': None,
#  'pygments.operator': None,
#  'logging.os': None,
#  'ctypes._endian': <module 'ctypes._endian' from '/Users/rob/anaconda/lib/python2.7/ctypes/_endian.pyc'>,
# ...
#  'pygments.filters.pygments': None,
#  'zmq.sugar.zmq': None,
#  'zmq.backend.sys': None,
#  'prompt_toolkit.terminal.os': None,
#  'prompt_toolkit.styles.base': <module 'prompt_toolkit.styles.base' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/styles/base.pyc'>,
#  'pygments.styles.pygments': None,
#  'IPython.lib.logging': None,
#  'ipykernel.zmqshell': <module 'ipykernel.zmqshell' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/zmqshell.pyc'>,
#  'IPython.utils.decorators': <module 'IPython.utils.decorators' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/decorators.pyc'>,
#  'IPython.testing.skipdoctest': <module 'IPython.testing.skipdoctest' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/testing/skipdoctest.pyc'>,
#  'email.binascii': None,
#  'IPython.core.magics.script': <module 'IPython.core.magics.script' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/script.pyc'>,
#  'sqlite3': <module 'sqlite3' from '/Users/rob/anaconda/lib/python2.7/sqlite3/__init__.pyc'>,
#  'pygments.formatters.pygments': None,
#  'prompt_toolkit.weakref': None,
#  'IPython.core.magics.basic': <module 'IPython.core.magics.basic' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/basic.pyc'>,
#  'pkg_resources.extern': <module 'pkg_resources.extern' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/extern/__init__.py'>,
#  'traitlets.config.traitlets': None,
#  'IPython.core.macro': <module 'IPython.core.macro' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/macro.pyc'>,
#  'IPython.core.magics.pprint': None,
#  'IPython.utils.data': <module 'IPython.utils.data' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/data.pyc'>,
#  'IPython.core.logger': <module 'IPython.core.logger' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/logger.pyc'>,
#  'json.json': None,
#  'IPython.terminal.ipapp': <module 'IPython.terminal.ipapp' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/ipapp.pyc'>,
#  'IPython.core.types': None,
#  'logging.logging': None,
#  'sys': <module 'sys' (built-in)>,
#  'IPython.terminal.IPython': None,
#  'multiprocessing.subprocess': None,
#  'IPython.core.string': None,
#  'email.cStringIO': None,
#  'jupyter_client.traitlets': None,
#  'IPython.terminal.pt_inputhooks.importlib': None,
#  'tornado.util': <module 'tornado.util' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/util.pyc'>,
#  'IPython.utils.importstring': <module 'IPython.utils.importstring' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/importstring.pyc'>,
#  'pkg_resources._vendor.packaging': <module 'pkg_resources._vendor.packaging' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/packaging/__init__.py'>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'pygments.formatters.__future__': None,
#  'IPython.core.inputtransformer': <module 'IPython.core.inputtransformer' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/inputtransformer.pyc'>,
#  'pkg_resources.extern.pyparsing': <module 'pkg_resources._vendor.pyparsing' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/pyparsing.py'>,
#  'urlparse': <module 'urlparse' from '/Users/rob/anaconda/lib/python2.7/urlparse.pyc'>,
#  'ipykernel.binascii': None,
#  'ctypes.macholib.dylib': <module 'ctypes.macholib.dylib' from '/Users/rob/anaconda/lib/python2.7/ctypes/macholib/dylib.pyc'>,
#  'pygments.cStringIO': None,
#  'ipywidgets.widgets.re': None,
#  'IPython.core.decorator': None,
#  'IPython.core.application': <module 'IPython.core.application' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/application.pyc'>,
#  'ipykernel._version': <module 'ipykernel._version' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/_version.pyc'>,
#  'IPython.core': <module 'IPython.core' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/__init__.pyc'>,
#  'prompt_toolkit.layout.processors': <module 'prompt_toolkit.layout.processors' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/layout/processors.pyc'>,
#  'IPython.core.pprint': None,
#  'traitlets.utils.six': None,
#  'pygments.formatters.fnmatch': None,
#  'prompt_toolkit.key_binding.registry': <module 'prompt_toolkit.key_binding.registry' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/key_binding/registry.pyc'>,
#  'heapq': <module 'heapq' from '/Users/rob/anaconda/lib/python2.7/heapq.pyc'>,
#  'concurrent.futures._base': <module 'concurrent.futures._base' from '/Users/rob/anaconda/lib/python2.7/site-packages/concurrent/futures/_base.pyc'>,
#  'concurrent.futures': <module 'concurrent.futures' from '/Users/rob/anaconda/lib/python2.7/site-packages/concurrent/futures/__init__.pyc'>,
#  'IPython.core.time': None,
#  'prompt_toolkit.terminal.array': None,
#  'prompt_toolkit.key_binding.bindings.completion': <module 'prompt_toolkit.key_binding.bindings.completion' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/key_binding/bindings/completion.pyc'>,
#  'IPython.extensions': <module 'IPython.extensions' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/extensions/__init__.pyc'>,
#  'ipykernel.pickleutil': <module 'ipykernel.pickleutil' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/pickleutil.pyc'>,
#  'ipykernel.iostream': <module 'ipykernel.iostream' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/iostream.pyc'>,
#  'ptyprocess.struct': None,
#  'zmq.backend.cython.socket': <module 'zmq.backend.cython.socket' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/socket.so'>,
#  'IPython.terminal.pt_inputhooks.os': None,
#  'IPython.core.oinspect': <module 'IPython.core.oinspect' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/oinspect.pyc'>,
#  'pkg_resources.extern.packaging': <module 'pkg_resources._vendor.packaging' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/packaging/__init__.py'>,
#  'zmq.sugar.time': None,
#  'prompt_toolkit.key_binding.bindings.codecs': None,
#  'zmq.sugar.attrsettr': <module 'zmq.sugar.attrsettr' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/attrsettr.pyc'>,
#  'email.mime': <module 'email.mime' from '/Users/rob/anaconda/lib/python2.7/email/mime/__init__.pyc'>,
#  'IPython.core.os': None,
#  'zmq.backend.cython.constants': <module 'zmq.backend.cython.constants' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/constants.so'>,
#  'ipython_genutils.path': <module 'ipython_genutils.path' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipython_genutils/path.pyc'>,
#  'ctypes.macholib.itertools': None,
#  'jupyter_client.logging': None,
#  'struct': <module 'struct' from '/Users/rob/anaconda/lib/python2.7/struct.pyc'>,
#  'xml.parsers.pyexpat': None,
#  'prompt_toolkit.terminal.prompt_toolkit': None,
#  'IPython.utils.strdispatch': <module 'IPython.utils.strdispatch' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/strdispatch.pyc'>,
#  'IPython.core.inputsplitter': <module 'IPython.core.inputsplitter' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/inputsplitter.pyc'>,
#  'IPython.utils.tokenize2': <module 'IPython.utils.tokenize2' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/tokenize2.pyc'>,
#  'prompt_toolkit.terminal.errno': None,
#  'IPython.lib': <module 'IPython.lib' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/__init__.pyc'>,
#  'sqlite3._sqlite3': None,
#  'prompt_toolkit.key_binding': <module 'prompt_toolkit.key_binding' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/key_binding/__init__.pyc'>,
#  'email.warnings': None,
#  'collections': <module 'collections' from '/Users/rob/anaconda/lib/python2.7/collections.pyc'>,
#  'jupyter_client.cPickle': None,
#  'pkg_resources._vendor.sys': None,
#  'prompt_toolkit.filters.collections': None,
#  'zmq.sugar.atexit': None,
#  'email.Parser': <email.LazyImporter at 0x108503490>,
#  'ipykernel.comm.comm': <module 'ipykernel.comm.comm' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/comm/comm.pyc'>,
#  'zmq.utils.sys': None,
#  'IPython.extensions.sys': None,
#  'backports.shutil_get_terminal_size.ctypes': None,
#  'traitlets.utils': <module 'traitlets.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/traitlets/utils/__init__.pyc'>,
#  'ipython_genutils.encoding': <module 'ipython_genutils.encoding' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipython_genutils/encoding.pyc'>,
#  'zipimport': <module 'zipimport' (built-in)>,
#  'IPython.core.struct': None,
#  'IPython.core.magics.execution': <module 'IPython.core.magics.execution' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc'>,
#  'pkg_resources.extern.sys': None,
#  'pkg_resources.extern.packaging.markers': <module 'pkg_resources._vendor.packaging.markers' from '/Users/rob/anaconda/lib/python2.7/site-packages/setuptools-27.2.0-py2.7.egg/pkg_resources/_vendor/packaging/markers.py'>,
#  'jupyter_client': <module 'jupyter_client' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/__init__.pyc'>,
#  'IPython.terminal.magics': <module 'IPython.terminal.magics' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/magics.pyc'>,
#  'textwrap': <module 'textwrap' from '/Users/rob/anaconda/lib/python2.7/textwrap.pyc'>,
#  'zmq.platform': None,
#  'curses': <module 'curses' from '/Users/rob/anaconda/lib/python2.7/curses/__init__.pyc'>,
#  'IPython.lib.subprocess': None,
#  'pkg_resources._vendor.threading': None,
#  'getopt': <module 'getopt' from '/Users/rob/anaconda/lib/python2.7/getopt.pyc'>,
#  'jupyter_client.channelsabc': <module 'jupyter_client.channelsabc' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/channelsabc.pyc'>,
#  'prompt_toolkit.filters.__future__': None,
#  'pexpect.traceback': None,
#  'ipykernel.math': None,
#  'traitlets.config.re': None,
#  'zmq.backend.cython._version': <module 'zmq.backend.cython._version' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/_version.so'>,
#  'pexpect.types': None,
#  'IPython.lib.random': None,
#  'ipykernel.codeutil': <module 'ipykernel.codeutil' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipykernel/codeutil.pyc'>,
#  'IPython.utils.frame': <module 'IPython.utils.frame' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/frame.pyc'>,
#  'signal': <module 'signal' (built-in)>,
#  'IPython.core.payloadpage': <module 'IPython.core.payloadpage' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/payloadpage.pyc'>,
#  'xml.parsers': <module 'xml.parsers' from '/Users/rob/anaconda/lib/python2.7/xml/parsers/__init__.pyc'>,
#  'prompt_toolkit.filters.abc': None,
#  'prompt_toolkit.re': None,
#  'IPython.terminal.warnings': None,
#  'prompt_toolkit.layout.containers': <module 'prompt_toolkit.layout.containers' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/layout/containers.pyc'>,
#  'quopri': <module 'quopri' from '/Users/rob/anaconda/lib/python2.7/quopri.pyc'>,
#  'IPython.core.magics': <module 'IPython.core.magics' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/__init__.pyc'>,
#  'pygments.lexers.types': None,
#  'IPython.core.getopt': None,
#  'jupyter_client.kernelspec': <module 'jupyter_client.kernelspec' from '/Users/rob/anaconda/lib/python2.7/site-packages/jupyter_client/kernelspec.pyc'>,
#  'IPython.utils.string': None,
#  'IPython.lib.display': <module 'IPython.lib.display' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/display.pyc'>,
#  'ipywidgets._version': <module 'ipywidgets._version' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/_version.pyc'>,
#  'IPython.terminal.prompts': <module 'IPython.terminal.prompts' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/prompts.pyc'>,
#  'mimetypes': <module 'mimetypes' from '/Users/rob/anaconda/lib/python2.7/mimetypes.pyc'>,
#  'IPython.core.magics.auto': <module 'IPython.core.magics.auto' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/auto.pyc'>,
#  'xml.parsers.expat': <module 'xml.parsers.expat' from '/Users/rob/anaconda/lib/python2.7/xml/parsers/expat.pyc'>,
#  'ipykernel.io': None,
#  'prompt_toolkit.key_binding.bindings.emacs': <module 'prompt_toolkit.key_binding.bindings.emacs' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/key_binding/bindings/emacs.pyc'>,
#  'pygments.lexers._mapping': <module 'pygments.lexers._mapping' from '/Users/rob/anaconda/lib/python2.7/site-packages/pygments/lexers/_mapping.pyc'>,
#  'IPython.utils.token': None,
#  'email.Generator': <email.LazyImporter at 0x108503950>,
#  'IPython.utils.module_paths': <module 'IPython.utils.module_paths' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/module_paths.pyc'>,
#  'pygments.lexers.os': None,
#  'logging.re': None,
#  'logging.traceback': None,
#  'IPython.core.magic_arguments': <module 'IPython.core.magic_arguments' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magic_arguments.pyc'>,
#  'pygments.codecs': None,
#  'traitlets.utils.getargspec': <module 'traitlets.utils.getargspec' from '/Users/rob/anaconda/lib/python2.7/site-packages/traitlets/utils/getargspec.pyc'>,
#  'IPython.core.magics.logging': <module 'IPython.core.magics.logging' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/logging.pyc'>,
#  'wcwidth.table_wide': <module 'wcwidth.table_wide' from '/Users/rob/anaconda/lib/python2.7/site-packages/wcwidth/table_wide.pyc'>,
#  'warnings': <module 'warnings' from '/Users/rob/anaconda/lib/python2.7/warnings.pyc'>,
#  'IPython.utils.sysinfo': <module 'IPython.utils.sysinfo' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/sysinfo.pyc'>,
#  'backports': <module 'backports' from '/Users/rob/anaconda/lib/python2.7/site-packages/backports/__init__.pyc'>,
#  'prompt_toolkit.key_binding.bindings.utils': <module 'prompt_toolkit.key_binding.bindings.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/key_binding/bindings/utils.pyc'>,
#  'IPython.lib.security': <module 'IPython.lib.security' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/security.pyc'>,
#  'prompt_toolkit.key_binding.digraphs': <module 'prompt_toolkit.key_binding.digraphs' from '/Users/rob/anaconda/lib/python2.7/site-packages/prompt_toolkit/key_binding/digraphs.pyc'>,
#  'IPython.core.subprocess': None,
#  'pygments.formatters.re': None,
#  'tornado.escape': <module 'tornado.escape' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/escape.pyc'>,
#  'traitlets.config.logging': None,
#  'ipython_genutils.warnings': None,
#  'IPython.lib.backgroundjobs': <module 'IPython.lib.backgroundjobs' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/backgroundjobs.pyc'>,
#  'IPython.utils.subprocess': None,
#  'jupyter_client.abc': None,
#  'prompt_toolkit.key_binding.bindings.itertools': None,
#  'IPython.utils.syspathcontext': <module 'IPython.utils.syspathcontext' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/syspathcontext.pyc'>,
#  'UserDict': <module 'UserDict' from '/Users/rob/anaconda/lib/python2.7/UserDict.pyc'>,
#  'traitlets.config.ipython_genutils': None,
#  'enum': <module 'enum' from '/Users/rob/anaconda/lib/python2.7/site-packages/enum/__init__.pyc'>,
#  'pygments.os': None,
#  'prompt_toolkit.prompt_toolkit': None,
#  'IPython.utils.PyColorize': <module 'IPython.utils.PyColorize' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/PyColorize.pyc'>,
#  'ipywidgets.widgets.widget_int': <module 'ipywidgets.widgets.widget_int' from '/Users/rob/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget_int.pyc'>,
#  'prompt_toolkit.time': None,
#  ...}

# %%
ip = get_ipython()

# %%
print "After reset, had 1: %s" % IPython
print "After reset, had 2: %s" % runipy
print "After reset, had 3: %s" % my_var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7fd4643b4d99> in <module>()
# ----> 1 print "After reset, had 1: %s" % IPython
#       2 print "After reset, had 2: %s" % runipy
#       3 print "After reset, had 3: %s" % my_var
#
# NameError: name 'IPython' is not defined

# %%
import runipy 
print "After reset, had 4: %s" % runipy.tempvar
# Out:
# After reset, had 4: temp value
