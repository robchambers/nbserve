# %%
import IPython
import runipy
my_var = "old value"
runipy.tempvar = "temp value"

# %%
print "Before reset, had 1: %s" % IPython
print "Before reset, had 2: %s" % runipy
print "Before reset, had 3: %s" % my_var
print "Before reset, had 4: %s" % runipy.tempvar

# %%
# %reset -f
import sys
sys.modules
del sys.modules['ConfigParser']
# Out:
# {'ConfigParser': <module 'ConfigParser' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/ConfigParser.pyc'>,
#  'IPython': <module 'IPython' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/__init__.pyc'>,
#  'IPython.IPython': None,
#  'IPython.config': <module 'IPython.config' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/config/__init__.pyc'>,
#  'IPython.config.IPython': None,
#  'IPython.config.__future__': None,
#  'IPython.config.application': <module 'IPython.config.application' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/config/application.pyc'>,
#  'IPython.config.argparse': None,
#  'IPython.config.collections': None,
#  'IPython.config.configurable': <module 'IPython.config.configurable' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/config/configurable.pyc'>,
#  'IPython.config.copy': None,
#  'IPython.config.json': None,
#  'IPython.config.loader': <module 'IPython.config.loader' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/config/loader.pyc'>,
#  'IPython.config.logging': None,
#  'IPython.config.os': None,
#  'IPython.config.re': None,
#  'IPython.config.sys': None,
#  'IPython.core': <module 'IPython.core' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/__init__.pyc'>,
#  'IPython.core.IPython': None,
#  'IPython.core.StringIO': None,
#  'IPython.core.__future__': None,
#  'IPython.core.__main__': None,
#  'IPython.core.abc': None,
#  'IPython.core.alias': <module 'IPython.core.alias' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/alias.pyc'>,
#  'IPython.core.application': <module 'IPython.core.application' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/application.pyc'>,
#  'IPython.core.argparse': None,
#  'IPython.core.ast': None,
#  'IPython.core.atexit': None,
#  'IPython.core.autocall': <module 'IPython.core.autocall' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/autocall.pyc'>,
#  'IPython.core.bdb': None,
#  'IPython.core.builtin_trap': <module 'IPython.core.builtin_trap' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/builtin_trap.pyc'>,
#  'IPython.core.codeop': None,
#  'IPython.core.compilerop': <module 'IPython.core.compilerop' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/compilerop.pyc'>,
#  'IPython.core.completer': <module 'IPython.core.completer' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/completer.pyc'>,
#  'IPython.core.completerlib': <module 'IPython.core.completerlib' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/completerlib.pyc'>,
#  'IPython.core.crashhandler': <module 'IPython.core.crashhandler' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/crashhandler.pyc'>,
#  'IPython.core.datetime': None,
#  'IPython.core.debugger': <module 'IPython.core.debugger' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/debugger.pyc'>,
#  'IPython.core.display': <module 'IPython.core.display' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/display.pyc'>,
#  'IPython.core.display_trap': <module 'IPython.core.display_trap' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/display_trap.pyc'>,
#  'IPython.core.displayhook': <module 'IPython.core.displayhook' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/displayhook.pyc'>,
#  'IPython.core.displaypub': <module 'IPython.core.displaypub' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/displaypub.pyc'>,
#  'IPython.core.docutils': None,
#  'IPython.core.errno': None,
#  'IPython.core.error': <module 'IPython.core.error' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/error.pyc'>,
#  'IPython.core.events': <module 'IPython.core.events' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/events.pyc'>,
#  'IPython.core.excolors': <module 'IPython.core.excolors' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/excolors.pyc'>,
#  'IPython.core.extensions': <module 'IPython.core.extensions' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/extensions.pyc'>,
#  'IPython.core.formatters': <module 'IPython.core.formatters' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc'>,
#  'IPython.core.functools': None,
#  'IPython.core.gc': None,
#  'IPython.core.getipython': <module 'IPython.core.getipython' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/getipython.pyc'>,
#  'IPython.core.getopt': None,
#  'IPython.core.glob': None,
#  'IPython.core.hashlib': None,
#  'IPython.core.history': <module 'IPython.core.history' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/history.pyc'>,
#  'IPython.core.hooks': <module 'IPython.core.hooks' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/hooks.pyc'>,
#  'IPython.core.imp': None,
#  'IPython.core.importlib': None,
#  'IPython.core.inputsplitter': <module 'IPython.core.inputsplitter' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/inputsplitter.pyc'>,
#  'IPython.core.inputtransformer': <module 'IPython.core.inputtransformer' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/inputtransformer.pyc'>,
#  'IPython.core.inspect': None,
#  'IPython.core.interactiveshell': <module 'IPython.core.interactiveshell' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc'>,
#  'IPython.core.io': None,
#  'IPython.core.itertools': None,
#  'IPython.core.keyword': None,
#  'IPython.core.linecache': None,
#  'IPython.core.logger': <module 'IPython.core.logger' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/logger.pyc'>,
#  'IPython.core.logging': None,
#  'IPython.core.macro': <module 'IPython.core.macro' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/macro.pyc'>,
#  'IPython.core.magic': <module 'IPython.core.magic' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc'>,
#  'IPython.core.magic_arguments': <module 'IPython.core.magic_arguments' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magic_arguments.pyc'>,
#  'IPython.core.magics': <module 'IPython.core.magics' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/__init__.pyc'>,
#  'IPython.core.magics.IPython': None,
#  'IPython.core.magics.StringIO': None,
#  'IPython.core.magics.__future__': None,
#  'IPython.core.magics.ast': None,
#  'IPython.core.magics.atexit': None,
#  'IPython.core.magics.auto': <module 'IPython.core.magics.auto' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/auto.pyc'>,
#  'IPython.core.magics.basic': <module 'IPython.core.magics.basic' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/basic.pyc'>,
#  'IPython.core.magics.bdb': None,
#  'IPython.core.magics.cProfile': None,
#  'IPython.core.magics.code': <module 'IPython.core.magics.code' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/code.pyc'>,
#  'IPython.core.magics.config': <module 'IPython.core.magics.config' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/config.pyc'>,
#  'IPython.core.magics.deprecated': <module 'IPython.core.magics.deprecated' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/deprecated.pyc'>,
#  'IPython.core.magics.display': <module 'IPython.core.magics.display' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/display.pyc'>,
#  'IPython.core.magics.errno': None,
#  'IPython.core.magics.execution': <module 'IPython.core.magics.execution' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc'>,
#  'IPython.core.magics.extension': <module 'IPython.core.magics.extension' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/extension.pyc'>,
#  'IPython.core.magics.gc': None,
#  'IPython.core.magics.history': <module 'IPython.core.magics.history' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/history.pyc'>,
#  'IPython.core.magics.inspect': None,
#  'IPython.core.magics.io': None,
#  'IPython.core.magics.itertools': None,
#  'IPython.core.magics.json': None,
#  'IPython.core.magics.logging': <module 'IPython.core.magics.logging' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/logging.pyc'>,
#  'IPython.core.magics.namespace': <module 'IPython.core.magics.namespace' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/namespace.pyc'>,
#  'IPython.core.magics.os': None,
#  'IPython.core.magics.osm': <module 'IPython.core.magics.osm' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/osm.pyc'>,
#  'IPython.core.magics.pdb': None,
#  'IPython.core.magics.pprint': None,
#  'IPython.core.magics.pstats': None,
#  'IPython.core.magics.pylab': <module 'IPython.core.magics.pylab' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/pylab.pyc'>,
#  'IPython.core.magics.re': None,
#  'IPython.core.magics.script': <module 'IPython.core.magics.script' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/magics/script.pyc'>,
#  'IPython.core.magics.signal': None,
#  'IPython.core.magics.subprocess': None,
#  'IPython.core.magics.sys': None,
#  'IPython.core.magics.time': None,
#  'IPython.core.oinspect': <module 'IPython.core.oinspect' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/oinspect.pyc'>,
#  'IPython.core.operator': None,
#  'IPython.core.os': None,
#  'IPython.core.page': <module 'IPython.core.page' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/page.pyc'>,
#  'IPython.core.payload': <module 'IPython.core.payload' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/payload.pyc'>,
#  'IPython.core.payloadpage': <module 'IPython.core.payloadpage' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/payloadpage.pyc'>,
#  'IPython.core.pdb': None,
#  'IPython.core.pprint': None,
#  'IPython.core.prefilter': <module 'IPython.core.prefilter' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/prefilter.pyc'>,
#  'IPython.core.profiledir': <module 'IPython.core.profiledir' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/profiledir.pyc'>,
#  'IPython.core.prompts': <module 'IPython.core.prompts' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/prompts.pyc'>,
#  'IPython.core.pydoc': None,
#  'IPython.core.pylabtools': <module 'IPython.core.pylabtools' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/pylabtools.pyc'>,
#  'IPython.core.re': None,
#  'IPython.core.release': <module 'IPython.core.release' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/release.pyc'>,
#  'IPython.core.shadowns': <module 'IPython.core.shadowns' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/shadowns.pyc'>,
#  'IPython.core.shellapp': <module 'IPython.core.shellapp' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/shellapp.pyc'>,
#  'IPython.core.shutil': None,
#  'IPython.core.socket': None,
#  'IPython.core.splitinput': <module 'IPython.core.splitinput' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/splitinput.pyc'>,
#  'IPython.core.sqlite3': None,
#  'IPython.core.string': None,
#  'IPython.core.struct': None,
#  'IPython.core.subprocess': None,
#  'IPython.core.sys': None,
#  'IPython.core.tempfile': None,
#  'IPython.core.threading': None,
#  'IPython.core.time': None,
#  'IPython.core.tokenize': None,
#  'IPython.core.traceback': None,
#  'IPython.core.types': None,
#  'IPython.core.ultratb': <module 'IPython.core.ultratb' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.pyc'>,
#  'IPython.core.usage': <module 'IPython.core.usage' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/core/usage.pyc'>,
#  'IPython.core.warnings': None,
#  'IPython.core.zipimport': None,
#  'IPython.display': <module 'IPython.display' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/display.pyc'>,
#  'IPython.extensions': <module 'IPython.extensions' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/extensions/__init__.pyc'>,
#  'IPython.extensions.IPython': None,
#  'IPython.extensions.__future__': None,
#  'IPython.extensions.inspect': None,
#  'IPython.extensions.os': None,
#  'IPython.extensions.storemagic': <module 'IPython.extensions.storemagic' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/extensions/storemagic.pyc'>,
#  'IPython.extensions.sys': None,
#  'IPython.extensions.textwrap': None,
#  'IPython.external': <module 'IPython.external' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/__init__.pyc'>,
#  'IPython.external.decorator': <module 'IPython.external.decorator' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/decorator/__init__.pyc'>,
#  'IPython.external.decorator.__future__': None,
#  'IPython.external.decorator._decorator': <module 'IPython.external.decorator._decorator' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/decorator/_decorator.pyc'>,
#  'IPython.external.decorator.functools': None,
#  'IPython.external.decorator.inspect': None,
#  'IPython.external.decorator.re': None,
#  'IPython.external.decorator.sys': None,
#  'IPython.external.path': <module 'IPython.external.path' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/path/__init__.pyc'>,
#  'IPython.external.path.__future__': None,
#  'IPython.external.path._path': <module 'IPython.external.path._path' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/path/_path.pyc'>,
#  'IPython.external.path.codecs': None,
#  'IPython.external.path.errno': None,
#  'IPython.external.path.fnmatch': None,
#  'IPython.external.path.functools': None,
#  'IPython.external.path.glob': None,
#  'IPython.external.path.hashlib': None,
#  'IPython.external.path.operator': None,
#  'IPython.external.path.os': None,
#  'IPython.external.path.pwd': None,
#  'IPython.external.path.re': None,
#  'IPython.external.path.shutil': None,
#  'IPython.external.path.sys': None,
#  'IPython.external.path.tempfile': None,
#  'IPython.external.path.warnings': None,
#  'IPython.external.pexpect': <module 'IPython.external.pexpect' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/pexpect/__init__.pyc'>,
#  'IPython.external.pexpect._pexpect': <module 'IPython.external.pexpect._pexpect' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/pexpect/_pexpect.pyc'>,
#  'IPython.external.pexpect.errno': None,
#  'IPython.external.pexpect.fcntl': None,
#  'IPython.external.pexpect.os': None,
#  'IPython.external.pexpect.pty': None,
#  'IPython.external.pexpect.re': None,
#  'IPython.external.pexpect.resource': None,
#  'IPython.external.pexpect.select': None,
#  'IPython.external.pexpect.signal': None,
#  'IPython.external.pexpect.struct': None,
#  'IPython.external.pexpect.sys': None,
#  'IPython.external.pexpect.termios': None,
#  'IPython.external.pexpect.time': None,
#  'IPython.external.pexpect.traceback': None,
#  'IPython.external.pexpect.tty': None,
#  'IPython.external.pexpect.types': None,
#  'IPython.external.simplegeneric': <module 'IPython.external.simplegeneric' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/simplegeneric/__init__.pyc'>,
#  'IPython.external.simplegeneric._simplegeneric': <module 'IPython.external.simplegeneric._simplegeneric' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/simplegeneric/_simplegeneric.pyc'>,
#  'IPython.external.simplegeneric.types': None,
#  'IPython.external.ssh': <module 'IPython.external.ssh' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/ssh/__init__.pyc'>,
#  'IPython.external.ssh.IPython': None,
#  'IPython.external.ssh.__future__': None,
#  'IPython.external.ssh.atexit': None,
#  'IPython.external.ssh.getpass': None,
#  'IPython.external.ssh.multiprocessing': None,
#  'IPython.external.ssh.os': None,
#  'IPython.external.ssh.signal': None,
#  'IPython.external.ssh.socket': None,
#  'IPython.external.ssh.sys': None,
#  'IPython.external.ssh.tunnel': <module 'IPython.external.ssh.tunnel' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/external/ssh/tunnel.pyc'>,
#  'IPython.external.ssh.warnings': None,
#  'IPython.html': <module 'IPython.html' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/html/__init__.pyc'>,
#  'IPython.html.IPython': None,
#  'IPython.html.__future__': None,
#  'IPython.html.nbextensions': <module 'IPython.html.nbextensions' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/html/nbextensions.pyc'>,
#  'IPython.html.os': None,
#  'IPython.html.shutil': None,
#  'IPython.html.tarfile': None,
#  'IPython.html.urllib': None,
#  'IPython.html.urlparse': None,
#  'IPython.html.zipfile': None,
#  'IPython.kernel': <module 'IPython.kernel' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/__init__.pyc'>,
#  'IPython.kernel.IPython': None,
#  'IPython.kernel.abc': None,
#  'IPython.kernel.blocking': <module 'IPython.kernel.blocking' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/blocking/__init__.pyc'>,
#  'IPython.kernel.blocking.IPython': None,
#  'IPython.kernel.blocking.Queue': None,
#  'IPython.kernel.blocking.channels': <module 'IPython.kernel.blocking.channels' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/blocking/channels.pyc'>,
#  'IPython.kernel.blocking.client': <module 'IPython.kernel.blocking.client' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/blocking/client.pyc'>,
#  'IPython.kernel.channels': <module 'IPython.kernel.channels' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/channels.pyc'>,
#  'IPython.kernel.channelsabc': <module 'IPython.kernel.channelsabc' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/channelsabc.pyc'>,
#  'IPython.kernel.client': <module 'IPython.kernel.client' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/client.pyc'>,
#  'IPython.kernel.clientabc': <module 'IPython.kernel.clientabc' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/clientabc.pyc'>,
#  'IPython.kernel.comm': <module 'IPython.kernel.comm' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/comm/__init__.pyc'>,
#  'IPython.kernel.comm.IPython': None,
#  'IPython.kernel.comm.comm': <module 'IPython.kernel.comm.comm' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/comm/comm.pyc'>,
#  'IPython.kernel.comm.manager': <module 'IPython.kernel.comm.manager' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/comm/manager.pyc'>,
#  'IPython.kernel.comm.sys': None,
#  'IPython.kernel.comm.uuid': None,
#  'IPython.kernel.connect': <module 'IPython.kernel.connect' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/connect.pyc'>,
#  'IPython.kernel.inprocess': <module 'IPython.kernel.inprocess' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/inprocess/__init__.pyc'>,
#  'IPython.kernel.inprocess.IPython': None,
#  'IPython.kernel.inprocess.Queue': None,
#  'IPython.kernel.inprocess.abc': None,
#  'IPython.kernel.inprocess.blocking': <module 'IPython.kernel.inprocess.blocking' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/inprocess/blocking.pyc'>,
#  'IPython.kernel.inprocess.channels': <module 'IPython.kernel.inprocess.channels' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/inprocess/channels.pyc'>,
#  'IPython.kernel.inprocess.client': <module 'IPython.kernel.inprocess.client' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/inprocess/client.pyc'>,
#  'IPython.kernel.inprocess.manager': <module 'IPython.kernel.inprocess.manager' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/inprocess/manager.pyc'>,
#  'IPython.kernel.inprocess.socket': <module 'IPython.kernel.inprocess.socket' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/inprocess/socket.pyc'>,
#  'IPython.kernel.inprocess.zmq': None,
#  'IPython.kernel.launcher': <module 'IPython.kernel.launcher' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/launcher.pyc'>,
#  'IPython.kernel.manager': <module 'IPython.kernel.manager' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/manager.pyc'>,
#  'IPython.kernel.managerabc': <module 'IPython.kernel.managerabc' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/managerabc.pyc'>,
#  'IPython.kernel.multikernelmanager': <module 'IPython.kernel.multikernelmanager' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/multikernelmanager.pyc'>,
#  'IPython.kernel.os': None,
#  'IPython.kernel.subprocess': None,
#  'IPython.kernel.sys': None,
#  'IPython.kernel.zmq': <module 'IPython.kernel.zmq' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/__init__.pyc'>,
#  'IPython.kernel.zmq.IPython': None,
#  'IPython.kernel.zmq.__future__': None,
#  'IPython.kernel.zmq.atexit': None,
#  'IPython.kernel.zmq.cPickle': None,
#  'IPython.kernel.zmq.ctypes': None,
#  'IPython.kernel.zmq.datapub': <module 'IPython.kernel.zmq.datapub' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/datapub.pyc'>,
#  'IPython.kernel.zmq.datetime': None,
#  'IPython.kernel.zmq.displayhook': <module 'IPython.kernel.zmq.displayhook' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/displayhook.pyc'>,
#  'IPython.kernel.zmq.errno': None,
#  'IPython.kernel.zmq.hashlib': None,
#  'IPython.kernel.zmq.heartbeat': <module 'IPython.kernel.zmq.heartbeat' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/heartbeat.pyc'>,
#  'IPython.kernel.zmq.hmac': None,
#  'IPython.kernel.zmq.io': None,
#  'IPython.kernel.zmq.iostream': <module 'IPython.kernel.zmq.iostream' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/iostream.pyc'>,
#  'IPython.kernel.zmq.ipkernel': <module 'IPython.kernel.zmq.ipkernel' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.pyc'>,
#  'IPython.kernel.zmq.json': None,
#  'IPython.kernel.zmq.kernelapp': <module 'IPython.kernel.zmq.kernelapp' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/kernelapp.pyc'>,
#  'IPython.kernel.zmq.logging': None,
#  'IPython.kernel.zmq.os': None,
#  'IPython.kernel.zmq.parentpoller': <module 'IPython.kernel.zmq.parentpoller' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/parentpoller.pyc'>,
#  'IPython.kernel.zmq.platform': None,
#  'IPython.kernel.zmq.pprint': None,
#  'IPython.kernel.zmq.random': None,
#  'IPython.kernel.zmq.serialize': <module 'IPython.kernel.zmq.serialize' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/serialize.pyc'>,
#  'IPython.kernel.zmq.session': <module 'IPython.kernel.zmq.session' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/session.pyc'>,
#  'IPython.kernel.zmq.signal': None,
#  'IPython.kernel.zmq.socket': None,
#  'IPython.kernel.zmq.sys': None,
#  'IPython.kernel.zmq.thread': None,
#  'IPython.kernel.zmq.threading': None,
#  'IPython.kernel.zmq.time': None,
#  'IPython.kernel.zmq.traceback': None,
#  'IPython.kernel.zmq.uuid': None,
#  'IPython.kernel.zmq.zmq': None,
#  'IPython.kernel.zmq.zmqshell': <module 'IPython.kernel.zmq.zmqshell' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/zmqshell.pyc'>,
#  'IPython.lib': <module 'IPython.lib' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/__init__.pyc'>,
#  'IPython.lib.IPython': None,
#  'IPython.lib.StringIO': None,
#  'IPython.lib.__future__': None,
#  'IPython.lib.backgroundjobs': <module 'IPython.lib.backgroundjobs' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/backgroundjobs.pyc'>,
#  'IPython.lib.base64': None,
#  'IPython.lib.clipboard': <module 'IPython.lib.clipboard' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/clipboard.pyc'>,
#  'IPython.lib.collections': None,
#  'IPython.lib.contextlib': None,
#  'IPython.lib.ctypes': None,
#  'IPython.lib.datetime': None,
#  'IPython.lib.deepreload': <module 'IPython.lib.deepreload' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/deepreload.pyc'>,
#  'IPython.lib.display': <module 'IPython.lib.display' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/display.pyc'>,
#  'IPython.lib.distutils': None,
#  'IPython.lib.getpass': None,
#  'IPython.lib.hashlib': None,
#  'IPython.lib.imp': None,
#  'IPython.lib.inputhook': <module 'IPython.lib.inputhook' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/inputhook.pyc'>,
#  'IPython.lib.io': None,
#  'IPython.lib.latextools': <module 'IPython.lib.latextools' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/latextools.pyc'>,
#  'IPython.lib.os': None,
#  'IPython.lib.pretty': <module 'IPython.lib.pretty' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc'>,
#  'IPython.lib.random': None,
#  'IPython.lib.re': None,
#  'IPython.lib.security': <module 'IPython.lib.security' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/lib/security.pyc'>,
#  'IPython.lib.select': None,
#  'IPython.lib.shutil': None,
#  'IPython.lib.signal': None,
#  'IPython.lib.subprocess': None,
#  'IPython.lib.sys': None,
#  'IPython.lib.tempfile': None,
#  'IPython.lib.threading': None,
#  'IPython.lib.types': None,
#  'IPython.lib.warnings': None,
#  'IPython.terminal': <module 'IPython.terminal' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/__init__.pyc'>,
#  'IPython.terminal.IPython': None,
#  'IPython.terminal.__future__': None,
#  'IPython.terminal.bdb': None,
#  'IPython.terminal.embed': <module 'IPython.terminal.embed' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/embed.pyc'>,
#  'IPython.terminal.interactiveshell': <module 'IPython.terminal.interactiveshell' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/interactiveshell.pyc'>,
#  'IPython.terminal.ipapp': <module 'IPython.terminal.ipapp' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/terminal/ipapp.pyc'>,
#  'IPython.terminal.os': None,
#  'IPython.terminal.sys': None,
#  'IPython.terminal.warnings': None,
#  'IPython.testing': <module 'IPython.testing' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/testing/__init__.pyc'>,
#  'IPython.testing.skipdoctest': <module 'IPython.testing.skipdoctest' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/testing/skipdoctest.pyc'>,
#  'IPython.testing.sys': None,
#  'IPython.utils': <module 'IPython.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/__init__.pyc'>,
#  'IPython.utils.IPython': None,
#  'IPython.utils.PyColorize': <module 'IPython.utils.PyColorize' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/PyColorize.pyc'>,
#  'IPython.utils.__builtin__': None,
#  'IPython.utils.__future__': None,
#  'IPython.utils._process_common': <module 'IPython.utils._process_common' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/_process_common.pyc'>,
#  'IPython.utils._process_posix': <module 'IPython.utils._process_posix' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/_process_posix.pyc'>,
#  'IPython.utils._sysinfo': <module 'IPython.utils._sysinfo' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/_sysinfo.pyc'>,
#  'IPython.utils._tokenize_py2': <module 'IPython.utils._tokenize_py2' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/_tokenize_py2.pyc'>,
#  'IPython.utils.base64': None,
#  'IPython.utils.cPickle': None,
#  'IPython.utils.capture': <module 'IPython.utils.capture' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/capture.pyc'>,
#  'IPython.utils.codeutil': <module 'IPython.utils.codeutil' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/codeutil.pyc'>,
#  'IPython.utils.collections': None,
#  'IPython.utils.coloransi': <module 'IPython.utils.coloransi' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/coloransi.pyc'>,
#  'IPython.utils.contextlib': None,
#  'IPython.utils.contexts': <module 'IPython.utils.contexts' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/contexts.pyc'>,
#  'IPython.utils.copy': None,
#  'IPython.utils.copy_reg': None,
#  'IPython.utils.data': <module 'IPython.utils.data' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/data.pyc'>,
#  'IPython.utils.datetime': None,
#  'IPython.utils.decorators': <module 'IPython.utils.decorators' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/decorators.pyc'>,
#  'IPython.utils.dir2': <module 'IPython.utils.dir2' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/dir2.pyc'>,
#  'IPython.utils.distutils': None,
#  'IPython.utils.encoding': <module 'IPython.utils.encoding' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/encoding.pyc'>,
#  'IPython.utils.errno': None,
#  'IPython.utils.frame': <module 'IPython.utils.frame' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/frame.pyc'>,
#  'IPython.utils.functools': None,
#  'IPython.utils.generics': <module 'IPython.utils.generics' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/generics.pyc'>,
#  'IPython.utils.glob': None,
#  'IPython.utils.hashlib': None,
#  'IPython.utils.imp': None,
#  'IPython.utils.importstring': <module 'IPython.utils.importstring' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/importstring.pyc'>,
#  'IPython.utils.inspect': None,
#  'IPython.utils.io': <module 'IPython.utils.io' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/io.pyc'>,
#  'IPython.utils.ipstruct': <module 'IPython.utils.ipstruct' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/ipstruct.pyc'>,
#  'IPython.utils.jsonutil': <module 'IPython.utils.jsonutil' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/jsonutil.pyc'>,
#  'IPython.utils.linecache': None,
#  'IPython.utils.locale': None,
#  'IPython.utils.localinterfaces': <module 'IPython.utils.localinterfaces' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/localinterfaces.pyc'>,
#  'IPython.utils.logging': None,
#  'IPython.utils.math': None,
#  'IPython.utils.module_paths': <module 'IPython.utils.module_paths' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/module_paths.pyc'>,
#  'IPython.utils.openpy': <module 'IPython.utils.openpy' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/openpy.pyc'>,
#  'IPython.utils.os': None,
#  'IPython.utils.path': <module 'IPython.utils.path' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/path.pyc'>,
#  'IPython.utils.pickleshare': <module 'IPython.utils.pickleshare' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/pickleshare.pyc'>,
#  'IPython.utils.pickleutil': <module 'IPython.utils.pickleutil' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/pickleutil.pyc'>,
#  'IPython.utils.platform': None,
#  'IPython.utils.pprint': None,
#  'IPython.utils.process': <module 'IPython.utils.process' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/process.pyc'>,
#  'IPython.utils.py3compat': <module 'IPython.utils.py3compat' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/py3compat.pyc'>,
#  'IPython.utils.random': None,
#  'IPython.utils.re': None,
#  'IPython.utils.resource': None,
#  'IPython.utils.rlineimpl': <module 'IPython.utils.rlineimpl' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/rlineimpl.pyc'>,
#  'IPython.utils.shlex': None,
#  'IPython.utils.shutil': None,
#  'IPython.utils.socket': None,
#  'IPython.utils.stat': None,
#  'IPython.utils.strdispatch': <module 'IPython.utils.strdispatch' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/strdispatch.pyc'>,
#  'IPython.utils.string': None,
#  'IPython.utils.struct': None,
#  'IPython.utils.subprocess': None,
#  'IPython.utils.sys': None,
#  'IPython.utils.sysinfo': <module 'IPython.utils.sysinfo' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/sysinfo.pyc'>,
#  'IPython.utils.syspathcontext': <module 'IPython.utils.syspathcontext' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/syspathcontext.pyc'>,
#  'IPython.utils.tempdir': <module 'IPython.utils.tempdir' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/tempdir.pyc'>,
#  'IPython.utils.tempfile': None,
#  'IPython.utils.terminal': <module 'IPython.utils.terminal' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/terminal.pyc'>,
#  'IPython.utils.text': <module 'IPython.utils.text' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/text.pyc'>,
#  'IPython.utils.textwrap': None,
#  'IPython.utils.time': None,
#  'IPython.utils.timing': <module 'IPython.utils.timing' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/timing.pyc'>,
#  'IPython.utils.token': None,
#  'IPython.utils.tokenize2': <module 'IPython.utils.tokenize2' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/tokenize2.pyc'>,
#  'IPython.utils.traitlets': <module 'IPython.utils.traitlets' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/traitlets.pyc'>,
#  'IPython.utils.types': None,
#  'IPython.utils.ulinecache': <module 'IPython.utils.ulinecache' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/ulinecache.pyc'>,
#  'IPython.utils.version': <module 'IPython.utils.version' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/version.pyc'>,
#  'IPython.utils.warn': <module 'IPython.utils.warn' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/warn.pyc'>,
#  'IPython.utils.warnings': None,
#  'IPython.utils.wildcard': <module 'IPython.utils.wildcard' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/wildcard.pyc'>,
#  'IPython.utils.zmq': None,
#  'IPython.utils.zmqrelated': <module 'IPython.utils.zmqrelated' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/utils/zmqrelated.pyc'>,
#  'Queue': <module 'Queue' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/Queue.pyc'>,
#  'StringIO': <module 'StringIO' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/StringIO.pyc'>,
#  'UserDict': <module 'UserDict' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/UserDict.pyc'>,
#  '__builtin__': <module '__builtin__' (built-in)>,
#  '__future__': <module '__future__' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/__future__.pyc'>,
#  '__main__': <module '__main__' (built-in)>,
#  '_abcoll': <module '_abcoll' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/_abcoll.pyc'>,
#  '_ast': <module '_ast' (built-in)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  '_collections': <module '_collections' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_collections.so'>,
#  '_ctypes': <module '_ctypes' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_ctypes.so'>,
#  '_curses': <module '_curses' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_curses.so'>,
#  '_functools': <module '_functools' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_functools.so'>,
#  '_hashlib': <module '_hashlib' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_hashlib.so'>,
#  '_heapq': <module '_heapq' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_heapq.so'>,
#  '_io': <module '_io' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_io.so'>,
#  '_json': <module '_json' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_json.so'>,
#  '_locale': <module '_locale' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_locale.so'>,
#  '_lsprof': <module '_lsprof' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_lsprof.so'>,
#  '_multiprocessing': <module '_multiprocessing' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_multiprocessing.so'>,
#  '_osx_support': <module '_osx_support' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/_osx_support.pyc'>,
#  '_random': <module '_random' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_random.so'>,
#  '_scproxy': <module '_scproxy' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_scproxy.so'>,
#  '_socket': <module '_socket' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_socket.so'>,
#  '_sqlite3': <module '_sqlite3' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_sqlite3.so'>,
#  '_sre': <module '_sre' (built-in)>,
#  '_ssl': <module '_ssl' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_ssl.so'>,
#  '_strptime': <module '_strptime' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/_strptime.pyc'>,
#  '_struct': <module '_struct' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/_struct.so'>,
#  '_sysconfigdata': <module '_sysconfigdata' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/_sysconfigdata.pyc'>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  '_weakrefset': <module '_weakrefset' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/_weakrefset.pyc'>,
#  'abc': <module 'abc' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/abc.pyc'>,
#  'argparse': <module 'argparse' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/argparse.pyc'>,
#  'ast': <module 'ast' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/ast.pyc'>,
#  'atexit': <module 'atexit' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/atexit.pyc'>,
#  'base64': <module 'base64' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/base64.pyc'>,
#  'bdb': <module 'bdb' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/bdb.pyc'>,
#  'binascii': <module 'binascii' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/binascii.so'>,
#  'cPickle': <module 'cPickle' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/cPickle.so'>,
#  'cProfile': <module 'cProfile' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/cProfile.pyc'>,
#  'cStringIO': <module 'cStringIO' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/cStringIO.so'>,
#  'calendar': <module 'calendar' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/calendar.pyc'>,
#  'cmd': <module 'cmd' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/cmd.pyc'>,
#  'codecs': <module 'codecs' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/codecs.pyc'>,
#  'codeop': <module 'codeop' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/codeop.pyc'>,
#  'collections': <module 'collections' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/collections.pyc'>,
#  'contextlib': <module 'contextlib' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/contextlib.pyc'>,
#  'copy': <module 'copy' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/copy.pyc'>,
#  'copy_reg': <module 'copy_reg' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/copy_reg.pyc'>,
#  'ctypes': <module 'ctypes' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/ctypes/__init__.pyc'>,
#  'ctypes._ctypes': None,
#  'ctypes._endian': <module 'ctypes._endian' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/ctypes/_endian.pyc'>,
#  'ctypes.ctypes': None,
#  'ctypes.macholib': <module 'ctypes.macholib' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/ctypes/macholib/__init__.pyc'>,
#  'ctypes.macholib.dyld': <module 'ctypes.macholib.dyld' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/ctypes/macholib/dyld.pyc'>,
#  'ctypes.macholib.dylib': <module 'ctypes.macholib.dylib' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/ctypes/macholib/dylib.pyc'>,
#  'ctypes.macholib.framework': <module 'ctypes.macholib.framework' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/ctypes/macholib/framework.pyc'>,
#  'ctypes.macholib.itertools': None,
#  'ctypes.macholib.os': None,
#  'ctypes.macholib.re': None,
#  'ctypes.os': None,
#  'ctypes.struct': None,
#  'ctypes.sys': None,
#  'ctypes.util': <module 'ctypes.util' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/ctypes/util.pyc'>,
#  'curses': <module 'curses' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/curses/__init__.pyc'>,
#  'curses._curses': None,
#  'curses.curses': None,
#  'curses.os': None,
#  'curses.sys': None,
#  'curses.wrapper': <module 'curses.wrapper' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/curses/wrapper.pyc'>,
#  'datetime': <module 'datetime' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/datetime.so'>,
#  'dis': <module 'dis' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/dis.pyc'>,
#  'distutils': <module 'distutils' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/distutils/__init__.pyc'>,
#  'distutils.re': None,
#  'distutils.string': None,
#  'distutils.types': None,
#  'distutils.version': <module 'distutils.version' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/distutils/version.pyc'>,
#  'docutils': <module 'docutils' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/__init__.pyc'>,
#  'docutils.ConfigParser': None,
#  'docutils.StringIO': None,
#  'docutils._compat': <module 'docutils._compat' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/_compat.pyc'>,
#  'docutils.codecs': None,
#  'docutils.core': <module 'docutils.core' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/core.pyc'>,
#  'docutils.docutils': None,
#  'docutils.frontend': <module 'docutils.frontend' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/frontend.pyc'>,
#  'docutils.io': <module 'docutils.io' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/io.pyc'>,
#  'docutils.languages': <module 'docutils.languages' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/languages/__init__.pyc'>,
#  'docutils.languages.docutils': None,
#  'docutils.languages.sys': None,
#  'docutils.nodes': <module 'docutils.nodes' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/nodes.pyc'>,
#  'docutils.optparse': None,
#  'docutils.os': None,
#  'docutils.parsers': <module 'docutils.parsers' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/parsers/__init__.pyc'>,
#  'docutils.parsers.docutils': None,
#  'docutils.parsers.sys': None,
#  'docutils.pprint': None,
#  'docutils.re': None,
#  'docutils.readers': <module 'docutils.readers' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/readers/__init__.pyc'>,
#  'docutils.readers.doctree': <module 'docutils.readers.doctree' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/readers/doctree.pyc'>,
#  'docutils.readers.docutils': None,
#  'docutils.readers.sys': None,
#  'docutils.sys': None,
#  'docutils.transforms': <module 'docutils.transforms' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/transforms/__init__.pyc'>,
#  'docutils.transforms.docutils': None,
#  'docutils.transforms.re': None,
#  'docutils.transforms.sys': None,
#  'docutils.transforms.time': None,
#  'docutils.transforms.universal': <module 'docutils.transforms.universal' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/transforms/universal.pyc'>,
#  'docutils.types': None,
#  'docutils.unicodedata': None,
#  'docutils.utils': <module 'docutils.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/utils/__init__.pyc'>,
#  'docutils.utils.codecs': None,
#  'docutils.utils.docutils': None,
#  'docutils.utils.error_reporting': <module 'docutils.utils.error_reporting' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/utils/error_reporting.pyc'>,
#  'docutils.utils.locale': None,
#  'docutils.utils.os': None,
#  'docutils.utils.re': None,
#  'docutils.utils.smartquotes': <module 'docutils.utils.smartquotes' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/utils/smartquotes.pyc'>,
#  'docutils.utils.sys': None,
#  'docutils.utils.unicodedata': None,
#  'docutils.utils.warnings': None,
#  'docutils.warnings': None,
#  'docutils.writers': <module 'docutils.writers' from '/Users/rob/anaconda/lib/python2.7/site-packages/docutils/writers/__init__.pyc'>,
#  'docutils.writers.docutils': None,
#  'docutils.writers.os': None,
#  'docutils.writers.sys': None,
#  'encodings': <module 'encodings' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/encodings/__init__.pyc'>,
#  'encodings.__builtin__': None,
#  'encodings.aliases': <module 'encodings.aliases' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/encodings/aliases.pyc'>,
#  'encodings.ascii': <module 'encodings.ascii' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/encodings/ascii.pyc'>,
#  'encodings.codecs': None,
#  'encodings.encodings': None,
#  'encodings.utf_8': <module 'encodings.utf_8' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/encodings/utf_8.pyc'>,
#  'errno': <module 'errno' (built-in)>,
#  'exceptions': <module 'exceptions' (built-in)>,
#  'fcntl': <module 'fcntl' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/fcntl.so'>,
#  'fnmatch': <module 'fnmatch' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/fnmatch.pyc'>,
#  'functools': <module 'functools' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/functools.pyc'>,
#  'gc': <module 'gc' (built-in)>,
#  'genericpath': <module 'genericpath' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/genericpath.pyc'>,
#  'getopt': <module 'getopt' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/getopt.pyc'>,
#  'getpass': <module 'getpass' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/getpass.pyc'>,
#  'gettext': <module 'gettext' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/gettext.pyc'>,
#  'glob': <module 'glob' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/glob.pyc'>,
#  'grp': <module 'grp' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/grp.so'>,
#  'hashlib': <module 'hashlib' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/hashlib.pyc'>,
#  'heapq': <module 'heapq' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/heapq.pyc'>,
#  'hmac': <module 'hmac' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/hmac.pyc'>,
#  'htmlentitydefs': <module 'htmlentitydefs' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/htmlentitydefs.pyc'>,
#  'imp': <module 'imp' (built-in)>,
#  'importlib': <module 'importlib' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/importlib/__init__.pyc'>,
#  'importlib.sys': None,
#  'inspect': <module 'inspect' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/inspect.pyc'>,
#  'io': <module 'io' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/io.pyc'>,
#  'itertools': <module 'itertools' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/itertools.so'>,
#  'json': <module 'json' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/json/__init__.pyc'>,
#  'json._json': None,
#  'json.decoder': <module 'json.decoder' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/json/decoder.pyc'>,
#  'json.encoder': <module 'json.encoder' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/json/encoder.pyc'>,
#  'json.json': None,
#  'json.re': None,
#  'json.scanner': <module 'json.scanner' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/json/scanner.pyc'>,
#  'json.struct': None,
#  'json.sys': None,
#  'keyword': <module 'keyword' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/keyword.pyc'>,
#  'linecache': <module 'linecache' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/linecache.pyc'>,
#  'locale': <module 'locale' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/locale.pyc'>,
#  'logging': <module 'logging' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/logging/__init__.pyc'>,
#  'logging.atexit': None,
#  'logging.cPickle': None,
#  'logging.cStringIO': None,
#  'logging.codecs': None,
#  'logging.collections': None,
#  'logging.errno': None,
#  'logging.handlers': <module 'logging.handlers' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/logging/handlers.pyc'>,
#  'logging.logging': None,
#  'logging.os': None,
#  'logging.re': None,
#  'logging.socket': None,
#  'logging.stat': None,
#  'logging.struct': None,
#  'logging.sys': None,
#  'logging.thread': None,
#  'logging.threading': None,
#  'logging.time': None,
#  'logging.traceback': None,
#  'logging.warnings': None,
#  'logging.weakref': None,
#  'marshal': <module 'marshal' (built-in)>,
#  'math': <module 'math' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/math.so'>,
#  'multiprocessing': <module 'multiprocessing' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/multiprocessing/__init__.pyc'>,
#  'multiprocessing._multiprocessing': None,
#  'multiprocessing.atexit': None,
#  'multiprocessing.itertools': None,
#  'multiprocessing.multiprocessing': None,
#  'multiprocessing.os': None,
#  'multiprocessing.process': <module 'multiprocessing.process' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/multiprocessing/process.pyc'>,
#  'multiprocessing.signal': None,
#  'multiprocessing.subprocess': None,
#  'multiprocessing.sys': None,
#  'multiprocessing.threading': None,
#  'multiprocessing.util': <module 'multiprocessing.util' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/multiprocessing/util.pyc'>,
#  'multiprocessing.weakref': None,
#  'numbers': <module 'numbers' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/numbers.pyc'>,
#  'opcode': <module 'opcode' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/opcode.pyc'>,
#  'operator': <module 'operator' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/operator.so'>,
#  'optparse': <module 'optparse' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/optparse.pyc'>,
#  'os': <module 'os' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/os.pyc'>,
#  'os.path': <module 'posixpath' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/posixpath.pyc'>,
#  'pdb': <module 'pdb' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/pdb.pyc'>,
#  'pickle': <module 'pickle' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/pickle.pyc'>,
#  'pkgutil': <module 'pkgutil' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/pkgutil.pyc'>,
#  'platform': <module 'platform' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/platform.pyc'>,
#  'posix': <module 'posix' (built-in)>,
#  'posixpath': <module 'posixpath' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/posixpath.pyc'>,
#  'pprint': <module 'pprint' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/pprint.pyc'>,
#  'pstats': <module 'pstats' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/pstats.pyc'>,
#  'pty': <module 'pty' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/pty.pyc'>,
#  'pwd': <module 'pwd' (built-in)>,
#  'pydap': <module 'pydap' (built-in)>,
#  'pydap.handlers': <module 'pydap.handlers' (built-in)>,
#  'pydap.responses': <module 'pydap.responses' (built-in)>,
#  'pydap.wsgi': <module 'pydap.wsgi' (built-in)>,
#  'pydoc': <module 'pydoc' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/pydoc.pyc'>,
#  'random': <module 'random' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/random.pyc'>,
#  're': <module 're' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/re.pyc'>,
#  'readline': <module 'readline' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/readline.so'>,
#  'repr': <module 'repr' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/repr.pyc'>,
#  'resource': <module 'resource' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/resource.so'>,
#  'runpy': <module 'runpy' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/runpy.pyc'>,
#  'select': <module 'select' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/select.so'>,
#  'shlex': <module 'shlex' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/shlex.pyc'>,
#  'shutil': <module 'shutil' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/shutil.pyc'>,
#  'signal': <module 'signal' (built-in)>,
#  'site': <module 'site' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/site.pyc'>,
#  'socket': <module 'socket' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/socket.pyc'>,
#  'sqlite3': <module 'sqlite3' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/sqlite3/__init__.pyc'>,
#  'sqlite3._sqlite3': None,
#  'sqlite3.collections': None,
#  'sqlite3.datetime': None,
#  'sqlite3.dbapi2': <module 'sqlite3.dbapi2' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/sqlite3/dbapi2.pyc'>,
#  'sqlite3.time': None,
#  'sre_compile': <module 'sre_compile' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/sre_compile.pyc'>,
#  'sre_constants': <module 'sre_constants' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/sre_constants.pyc'>,
#  'sre_parse': <module 'sre_parse' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/sre_parse.pyc'>,
#  'ssl': <module 'ssl' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/ssl.pyc'>,
#  'stat': <module 'stat' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/stat.pyc'>,
#  'storemagic': <module 'storemagic' from '/Users/rob/anaconda/lib/python2.7/site-packages/IPython/extensions/storemagic.pyc'>,
#  'string': <module 'string' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/string.pyc'>,
#  'strop': <module 'strop' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/strop.so'>,
#  'struct': <module 'struct' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/struct.pyc'>,
#  'subprocess': <module 'subprocess' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/subprocess.pyc'>,
#  'sys': <module 'sys' (built-in)>,
#  'sysconfig': <module 'sysconfig' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/sysconfig.pyc'>,
#  'tarfile': <module 'tarfile' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/tarfile.pyc'>,
#  'tempfile': <module 'tempfile' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/tempfile.pyc'>,
#  'termios': <module 'termios' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/termios.so'>,
#  'textwrap': <module 'textwrap' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/textwrap.pyc'>,
#  'thread': <module 'thread' (built-in)>,
#  'threading': <module 'threading' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/threading.pyc'>,
#  'time': <module 'time' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/time.so'>,
#  'token': <module 'token' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/token.pyc'>,
#  'tokenize': <module 'tokenize' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/tokenize.pyc'>,
#  'tornado': <module 'tornado' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/__init__.pyc'>,
#  'tornado.concurrent': <module 'tornado.concurrent' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/concurrent.pyc'>,
#  'tornado.escape': <module 'tornado.escape' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/escape.pyc'>,
#  'tornado.ioloop': <module 'tornado.ioloop' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/ioloop.pyc'>,
#  'tornado.log': <module 'tornado.log' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/log.pyc'>,
#  'tornado.platform': <module 'tornado.platform' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/platform/__init__.pyc'>,
#  'tornado.platform.auto': <module 'tornado.platform.auto' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/platform/auto.pyc'>,
#  'tornado.platform.interface': <module 'tornado.platform.interface' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/platform/interface.pyc'>,
#  'tornado.platform.posix': <module 'tornado.platform.posix' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/platform/posix.pyc'>,
#  'tornado.stack_context': <module 'tornado.stack_context' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/stack_context.pyc'>,
#  'tornado.util': <module 'tornado.util' from '/Users/rob/anaconda/lib/python2.7/site-packages/tornado/util.pyc'>,
#  'traceback': <module 'traceback' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/traceback.pyc'>,
#  'tty': <module 'tty' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/tty.pyc'>,
#  'types': <module 'types' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/types.pyc'>,
#  'unicodedata': <module 'unicodedata' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/unicodedata.so'>,
#  'urllib': <module 'urllib' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/urllib.pyc'>,
#  'urlparse': <module 'urlparse' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/urlparse.pyc'>,
#  'uuid': <module 'uuid' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/uuid.pyc'>,
#  'warnings': <module 'warnings' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/warnings.pyc'>,
#  'weakref': <module 'weakref' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/weakref.pyc'>,
#  'zipfile': <module 'zipfile' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/zipfile.pyc'>,
#  'zipimport': <module 'zipimport' (built-in)>,
#  'zlib': <module 'zlib' from '/Users/rob/anaconda/python.app/Contents/lib/python2.7/lib-dynload/zlib.so'>,
#  'zmq': <module 'zmq' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/__init__.pyc'>,
#  'zmq.backend': <module 'zmq.backend' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/__init__.pyc'>,
#  'zmq.backend.cython': <module 'zmq.backend.cython' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/__init__.pyc'>,
#  'zmq.backend.cython._device': <module 'zmq.backend.cython._device' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/_device.so'>,
#  'zmq.backend.cython._poll': <module 'zmq.backend.cython._poll' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/_poll.so'>,
#  'zmq.backend.cython._version': <module 'zmq.backend.cython._version' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/_version.so'>,
#  'zmq.backend.cython.cPickle': None,
#  'zmq.backend.cython.codecs': None,
#  'zmq.backend.cython.constants': <module 'zmq.backend.cython.constants' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/constants.so'>,
#  'zmq.backend.cython.context': <module 'zmq.backend.cython.context' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/context.so'>,
#  'zmq.backend.cython.copy': None,
#  'zmq.backend.cython.error': <module 'zmq.backend.cython.error' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/error.so'>,
#  'zmq.backend.cython.message': <module 'zmq.backend.cython.message' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/message.so'>,
#  'zmq.backend.cython.random': None,
#  'zmq.backend.cython.socket': <module 'zmq.backend.cython.socket' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/socket.so'>,
#  'zmq.backend.cython.struct': None,
#  'zmq.backend.cython.sys': None,
#  'zmq.backend.cython.threading': None,
#  'zmq.backend.cython.time': None,
#  'zmq.backend.cython.utils': <module 'zmq.backend.cython.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/cython/utils.so'>,
#  'zmq.backend.cython.zmq': None,
#  'zmq.backend.os': None,
#  'zmq.backend.platform': None,
#  'zmq.backend.select': <module 'zmq.backend.select' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/backend/select.pyc'>,
#  'zmq.backend.sys': None,
#  'zmq.backend.zmq': None,
#  'zmq.devices': <module 'zmq.devices' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/devices/__init__.pyc'>,
#  'zmq.devices.basedevice': <module 'zmq.devices.basedevice' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/devices/basedevice.pyc'>,
#  'zmq.devices.monitoredqueue': <module 'zmq.devices.monitoredqueue' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/devices/monitoredqueue.so'>,
#  'zmq.devices.monitoredqueuedevice': <module 'zmq.devices.monitoredqueuedevice' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/devices/monitoredqueuedevice.pyc'>,
#  'zmq.devices.multiprocessing': None,
#  'zmq.devices.proxydevice': <module 'zmq.devices.proxydevice' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/devices/proxydevice.pyc'>,
#  'zmq.devices.threading': None,
#  'zmq.devices.time': None,
#  'zmq.devices.zmq': None,
#  'zmq.error': <module 'zmq.error' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/error.pyc'>,
#  'zmq.eventloop': <module 'zmq.eventloop' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/eventloop/__init__.pyc'>,
#  'zmq.eventloop.Queue': None,
#  'zmq.eventloop.__future__': None,
#  'zmq.eventloop.cPickle': None,
#  'zmq.eventloop.ioloop': <module 'zmq.eventloop.ioloop' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/eventloop/ioloop.pyc'>,
#  'zmq.eventloop.sys': None,
#  'zmq.eventloop.tornado': None,
#  'zmq.eventloop.zmq': None,
#  'zmq.eventloop.zmqstream': <module 'zmq.eventloop.zmqstream' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/eventloop/zmqstream.pyc'>,
#  'zmq.glob': None,
#  'zmq.os': None,
#  'zmq.sugar': <module 'zmq.sugar' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/__init__.pyc'>,
#  'zmq.sugar.atexit': None,
#  'zmq.sugar.attrsettr': <module 'zmq.sugar.attrsettr' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/attrsettr.pyc'>,
#  'zmq.sugar.cPickle': None,
#  'zmq.sugar.codecs': None,
#  'zmq.sugar.constants': <module 'zmq.sugar.constants' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/constants.pyc'>,
#  'zmq.sugar.context': <module 'zmq.sugar.context' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/context.pyc'>,
#  'zmq.sugar.frame': <module 'zmq.sugar.frame' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/frame.pyc'>,
#  'zmq.sugar.poll': <module 'zmq.sugar.poll' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/poll.pyc'>,
#  'zmq.sugar.random': None,
#  'zmq.sugar.socket': <module 'zmq.sugar.socket' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/socket.pyc'>,
#  'zmq.sugar.threading': None,
#  'zmq.sugar.time': None,
#  'zmq.sugar.tracker': <module 'zmq.sugar.tracker' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/tracker.pyc'>,
#  'zmq.sugar.version': <module 'zmq.sugar.version' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/sugar/version.pyc'>,
#  'zmq.sugar.warnings': None,
#  'zmq.sugar.weakref': None,
#  'zmq.sugar.zmq': None,
#  'zmq.sys': None,
#  'zmq.utils': <module 'zmq.utils' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/utils/__init__.pyc'>,
#  'zmq.utils.constant_names': <module 'zmq.utils.constant_names' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/utils/constant_names.pyc'>,
#  'zmq.utils.interop': <module 'zmq.utils.interop' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/utils/interop.pyc'>,
#  'zmq.utils.jsonapi': <module 'zmq.utils.jsonapi' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/utils/jsonapi.pyc'>,
#  'zmq.utils.sixcerpt': <module 'zmq.utils.sixcerpt' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/utils/sixcerpt.pyc'>,
#  'zmq.utils.strtypes': <module 'zmq.utils.strtypes' from '/Users/rob/anaconda/lib/python2.7/site-packages/zmq/utils/strtypes.pyc'>,
#  'zmq.utils.sys': None,
#  'zmq.utils.zmq': None,
#  'zmq.zipimport': None,
#  'zmq.zmq': None}

# %%
print "After reset, had 1: %s" % IPython

# %%
print "After reset, had 2: %s" % runipy

# %%
print "After reset, had 3: %s" % my_var

# %%
import runipy
print "After reset, had 4: %s" % runipy.tempvar
